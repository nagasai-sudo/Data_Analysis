# %% [markdown]
# # Project - Task 2

# %% [markdown]
# This notebook contains task 2 of the project 2.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Reading the data from csv file saved earlier in task 1

# %%
papers_df = pd.read_csv('Arxiv_Papers_Results.csv')

# %%
papers_df
# Out:
#                                                    Title  \
# 0      A Tutorial on Modular Ontology Modeling with O...
# 1                                The Book of Why: Review
# 2      AI Buzzwords Explained: Multi-Agent Path Findi...
# 3      AAAI FSS-18: Artificial Intelligence in Govern...
# 4           Self-Learned Formula Synthesis in Set Theory
# ...                                                  ...
# 49663  Brain-inspired Cognition in Next Generation Ra...
# 49664  MC-CIM: Compute-in-Memory with Monte-Carlo Dro...
# 49665  Logic Shrinkage: Learned FPGA Netlist Sparsity...
# 49666  First-Generation Inference Accelerator Deploym...
# 49667  Applications and Techniques for Fast Machine L...
#
#                                                   Author  \
# 0                    'Pascal Hitzler', 'Adila Krisnadhi'
# 1                                    'Joseph Y. Halpern'
# 2                               'Hang Ma', 'Sven Koenig'
# ...

# %%
#Checking the unique categories in primary category to confirm if we have only our desired categories
print(pd.unique(papers_df['Primary_category']))
# Out:
# ['cs.AI' 'cs.LG' 'cs.CC' 'cs.AR']

# %%
type(papers_df['Published_date'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# Converting the published date to datetime datatype.

# %% [markdown]
# Doing this step here because we are not to read csv file again and again in later tasks.

# %%
pd.to_datetime(papers_df['Published_date'])
# Out:
# 0       2018-08-25 14:36:00+00:00
# 1       2019-09-30 07:11:50+00:00
# 2       2017-10-10 18:24:34+00:00
# 3       2018-10-14 11:40:30+00:00
# 4       2019-12-03 16:56:51+00:00
#                    ...
# 49663   2021-11-03 14:21:39+00:00
# 49664   2021-11-13 14:50:48+00:00
# 49665   2021-12-04 14:23:24+00:00
# 49666   2021-07-08 22:52:42+00:00
# 49667   2021-10-25 15:25:25+00:00
# Name: Published_date, Length: 49668, dtype: datetime64[ns, UTC]

# %% [markdown]
# Creating dataframes for each of the primary categories

# %%
#Artificial Intelligence dataframe
AI_papers_df = papers_df[papers_df['Primary_category'] == 'cs.AI']

#Machine Learning dataframe
ML_papers_df = papers_df[papers_df['Primary_category'] == 'cs.LG']

#Computational Complexity Dataframe
CC_papers_df = papers_df[papers_df['Primary_category'] == 'cs.CC']

#Harware Architecture Dataframe
AR_papers_df = papers_df[papers_df['Primary_category'] == 'cs.AR']

# %% [markdown]
# # Showing the top 5 rows of each category

# %% [markdown]
# Artificial Intelligence top 5 results

# %%
#Artificial Intelligence top 5 results using pandas head function
AI_papers_df.head(5)
# Out:
#                                                Title  \
# 0  A Tutorial on Modular Ontology Modeling with O...
# 1                            The Book of Why: Review
# 2  AI Buzzwords Explained: Multi-Agent Path Findi...
# 3  AAAI FSS-18: Artificial Intelligence in Govern...
# 4       Self-Learned Formula Synthesis in Set Theory
#
#                                         Author  \
# 0          'Pascal Hitzler', 'Adila Krisnadhi'
# 1                          'Joseph Y. Halpern'
# 2                     'Hang Ma', 'Sven Koenig'
# 3  'Frank Stein', 'Alun Preece', 'Mihai Boicu'
# 4         'Chad E. Brown', 'Thibault Gauthier'
#
#                                              Summary  \
# 0  We provide a detailed example for modular onto...
# 1  This is a review of "The Book of Why", by Jude...
# 2  Explanation of the hot topic "multi-agent path...
# 3  Proceedings of the AAAI Fall Symposium on Arti...
# 4  A reinforcement learning algorithm accomplishe...
#
# ...

# %% [markdown]
# Machine Learning top 5 results

# %%
#Machine Learning top 5 results using pandas head function

ML_papers_df.head(5)
# Out:
#                                                   Title  \
# 227   Is AmI (Attacks Meet Interpretability) Robust ...
# 1224  Catastrophic Importance of Catastrophic Forget...
# 1225  Quadratic Suffices for Over-parametrization vi...
# 1226      Paranom: A Parallel Anomaly Dataset Generator
# 1227  MagNet and "Efficient Defenses Against Adversa...
#
#                                   Author  \
# 227                   'Nicholas Carlini'
# 1224                  'Albert Ierusalem'
# 1225             'Zhao Song', 'Xin Yang'
# 1226                'Justin Gottschlich'
# 1227  'Nicholas Carlini', 'David Wagner'
#
#                                                 Summary Comment Journal_ref  \
# 227                                                 No.     NaN         NaN
# 1224  This paper describes some of the possibilities...     NaN         NaN
# 1225  We improve the over-parametrization size over ...     NaN         NaN
# ...

# %% [markdown]
# Computational Complexity top 5 results

# %%
#Computational Complexity top 5 results using head function

CC_papers_df.head(5)
# Out:
#                                                   Title  \
# 1229                     Hyperbolic Minesweeper is in P
# 1234   Knowledge compilation languages as proof systems
# 1247  Expressing Linear Orders Requires Exponential-...
# 1261  On Computation Complexity of True Proof Number...
# 1264                    Super Solutions of the Model RB
#
#                          Author  \
# 1229          'Eryk Kopczyński'
# 1234          'Florent Capelli'
# 1247           'Ronald de Haan'
# 1261                 'Chao Gao'
# 1264  'Guangyan Zhou', 'Wei Xu'
#
#                                                 Summary  \
# 1229  We show that, while Minesweeper is NP-complete...
# 1234  In this paper, we study proof systems in the s...
# 1247  We show that any DNNF circuit that expresses t...
# 1261  We point out that the computation of true \emp...
# 1264  The concept of super solution is a special typ...
#
#                                                 Comment Journal_ref  DOI  \
# ...

# %% [markdown]
# Hardware Architecture top 5 results

# %%
#Hardware Architecture top 5 results using pandas head function

AR_papers_df.head(5)
# Out:
#                                                   Title  \
# 5925  Proceedings of the DATE Friday Workshop on Sys...
# 5975  CoDR: Computation and Data Reuse Aware CNN Acc...
# 9029  Optimizing Routerless Network-on-Chip Designs:...
# 9194  A Survey of Machine Learning Applied to Comput...
# 9415  A Streaming Accelerator for Deep Convolutional...
#
#                                                  Author  \
# 5925  'Frank Hannig', 'Paolo Meloni', 'Matteo Spalla...
# 5975      'Alireza Khadem', 'Haojie Ye', 'Trevor Mudge'
# 9029  'Ting-Ru Lin', 'Drew Penney', 'Massoud Pedram'...
# 9194                   'Drew D. Penney', 'Lizhong Chen'
# 9415  'Yuan Du', 'Li Du', 'Yilei Li', 'Junjie Su', '...
#
#                                                 Summary  \
# 5925  This volume contains the papers accepted at th...
# 5975  Computation and Data Reuse is critical for the...
# 9029  Machine learning applied to architecture desig...
# 9194  Machine learning has enabled significant benef...
# ...

# %% [markdown]
# Store all these variables & results so that we can access them easily in the next tasks.

# %%
# %store papers_df

# %store AI_papers_df

# %store ML_papers_df

# %store CC_papers_df

# %store AR_papers_df
# Out:
# Stored 'papers_df' (DataFrame)
# Stored 'AI_papers_df' (DataFrame)
# Stored 'ML_papers_df' (DataFrame)
# Stored 'CC_papers_df' (DataFrame)
# Stored 'AR_papers_df' (DataFrame)
