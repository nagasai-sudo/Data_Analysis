# %% [markdown]
# # Data Analysis Project
#
# Arxiv hosts lot of published research papers. We are using the Arxiv API to access the metadata of research papers and do the rest of tasks.

# %%
import arxiv
import json 
import time
import numpy as np
import pandas as pd
import pickle

# %% [markdown]
# Defined a function below called get_results to get the papers results in category wise.
#
# The following query retrieves all the papers with category code, We will later filter the data according to primary codes.
# In the query setting, put the category code.
# Collect the paper result in a list.
# Even though we get error on the basis of UnexpectedEmptyPageError, our list will contain information.

# %%
def get_results(category):
    results = arxiv.Client(
    page_size=2000, delay_seconds=3, num_retries=3).results(
        arxiv.Search(
            query = category,
            sort_order=arxiv.SortOrder.Descending,
        ))
    return results

paper_results = [] # this is the list that hosts all the papers information.

# %% [markdown]
# Using the get_results function to append each of the category results into papers_results list

# %%
#First usage of get_results function to append all the papers with 'cs.AI' as category.

AI_results = get_results('cs.AI')
for AI_papers in AI_results:
    paper_results.append(AI_papers)
# Out:
# ---------------------------------------------------------------------------
# UnexpectedEmptyPageError                  Traceback (most recent call last)
# Input In [41], in <cell line: 4>()
#       1 #First usage of get_results function to append all the papers with 'cs.AI' as category.
#       3 AI_results = get_results('cs.AI')
# ----> 4 for AI_papers in AI_results:
#       5     paper_results.append(AI_papers)
#
# File ~\anaconda3\lib\site-packages\arxiv\arxiv.py:585, in Client.results(self, search)
#     580 logger.info("Requesting {} results at offset {}".format(
#     581     page_size,
#     582     offset,
#     583 ))
#     584 page_url = self._format_url(search, offset, page_size)
# --> 585 feed = self._parse_feed(page_url, first_page)
#     586 if first_page:
#     587     # NOTE: this is an ugly fix for a known bug. The totalresults
#     588     # value is set to 1 for results with zero entries. If that API
#     589     # bug is fixed, we can remove this conditional and always set
#     590     # `total_results = min(...)`.
#     591     if len(feed.entries) == 0:
#
# File ~\anaconda3\lib\site-packages\arxiv\arxiv.py:639, in Client._parse_feed(self, url, first_page)
#     632 """
#     633 Fetches the specified URL and parses it with feedparser.
#     634
#     635 If a request fails or is unexpectedly empty, retries the request up to
#     636 `self.num_retries` times.
#     637 """
#     638 # Invoke the recursive helper with initial available retries.
# --> 639 return self.__try_parse_feed(
#     640     url,
#     641     first_page=first_page,
#     642     retries_left=self.num_retries
#     643 )
#
# File ~\anaconda3\lib\site-packages\arxiv\arxiv.py:681, in Client.__try_parse_feed(self, url, first_page, retries_left, last_err)
#     679 if err is not None:
#     680     if retries_left > 0:
# --> 681         return self.__try_parse_feed(
#     682             url,
#     683             first_page=first_page,
#     684             retries_left=retries_left-1,
#     685             last_err=err,
#     686         )
#     687     # Feed was never returned in self.num_retries tries. Raise the last
#     688     # exception encountered.
#     689     raise err
#
# File ~\anaconda3\lib\site-packages\arxiv\arxiv.py:681, in Client.__try_parse_feed(self, url, first_page, retries_left, last_err)
#     679 if err is not None:
#     680     if retries_left > 0:
# --> 681         return self.__try_parse_feed(
#     682             url,
#     683             first_page=first_page,
#     684             retries_left=retries_left-1,
#     685             last_err=err,
#     686         )
#     687     # Feed was never returned in self.num_retries tries. Raise the last
#     688     # exception encountered.
#     689     raise err
#
# File ~\anaconda3\lib\site-packages\arxiv\arxiv.py:681, in Client.__try_parse_feed(self, url, first_page, retries_left, last_err)
#     679 if err is not None:
#     680     if retries_left > 0:
# --> 681         return self.__try_parse_feed(
#     682             url,
#     683             first_page=first_page,
#     684             retries_left=retries_left-1,
#     685             last_err=err,
#     686         )
#     687     # Feed was never returned in self.num_retries tries. Raise the last
#     688     # exception encountered.
#     689     raise err
#
# File ~\anaconda3\lib\site-packages\arxiv\arxiv.py:689, in Client.__try_parse_feed(self, url, first_page, retries_left, last_err)
#     681         return self.__try_parse_feed(
#     682             url,
#     683             first_page=first_page,
#     684             retries_left=retries_left-1,
#     685             last_err=err,
#     686         )
#     687     # Feed was never returned in self.num_retries tries. Raise the last
#     688     # exception encountered.
# --> 689     raise err
#     690 return feed
#
# UnexpectedEmptyPageError: Page of results was unexpectedly empty (http://export.arxiv.org/api/query?search_query=cs.AI&id_list=&sortBy=relevance&sortOrder=descending&start=50000&max_results=2000)

# %%
len(paper_results) # to confirm or view how many results we get
# Out:
# 50000

# %%
# Using of get_results function to append all the papers with 'cs.LG' or Machine learning as category.

LG_results = get_results('cs.LG')

for LG_papers in LG_results:
    paper_results.append(LG_papers)
# Out:
# ---------------------------------------------------------------------------
# UnexpectedEmptyPageError                  Traceback (most recent call last)
# Input In [43], in <cell line: 5>()
#       1 # Using of get_results function to append all the papers with 'cs.LG' or Machine learning as category.
#       3 LG_results = get_results('cs.LG')
# ----> 5 for LG_papers in LG_results:
#       6     paper_results.append(LG_papers)
#
# File ~\anaconda3\lib\site-packages\arxiv\arxiv.py:585, in Client.results(self, search)
#     580 logger.info("Requesting {} results at offset {}".format(
#     581     page_size,
#     582     offset,
#     583 ))
#     584 page_url = self._format_url(search, offset, page_size)
# --> 585 feed = self._parse_feed(page_url, first_page)
#     586 if first_page:
#     587     # NOTE: this is an ugly fix for a known bug. The totalresults
#     588     # value is set to 1 for results with zero entries. If that API
#     589     # bug is fixed, we can remove this conditional and always set
#     590     # `total_results = min(...)`.
#     591     if len(feed.entries) == 0:
#
# File ~\anaconda3\lib\site-packages\arxiv\arxiv.py:639, in Client._parse_feed(self, url, first_page)
#     632 """
#     633 Fetches the specified URL and parses it with feedparser.
#     634
#     635 If a request fails or is unexpectedly empty, retries the request up to
#     636 `self.num_retries` times.
#     637 """
#     638 # Invoke the recursive helper with initial available retries.
# --> 639 return self.__try_parse_feed(
#     640     url,
#     641     first_page=first_page,
#     642     retries_left=self.num_retries
#     643 )
#
# File ~\anaconda3\lib\site-packages\arxiv\arxiv.py:681, in Client.__try_parse_feed(self, url, first_page, retries_left, last_err)
#     679 if err is not None:
#     680     if retries_left > 0:
# --> 681         return self.__try_parse_feed(
#     682             url,
#     683             first_page=first_page,
#     684             retries_left=retries_left-1,
#     685             last_err=err,
#     686         )
#     687     # Feed was never returned in self.num_retries tries. Raise the last
#     688     # exception encountered.
#     689     raise err
#
# File ~\anaconda3\lib\site-packages\arxiv\arxiv.py:681, in Client.__try_parse_feed(self, url, first_page, retries_left, last_err)
#     679 if err is not None:
#     680     if retries_left > 0:
# --> 681         return self.__try_parse_feed(
#     682             url,
#     683             first_page=first_page,
#     684             retries_left=retries_left-1,
#     685             last_err=err,
#     686         )
#     687     # Feed was never returned in self.num_retries tries. Raise the last
#     688     # exception encountered.
#     689     raise err
#
# File ~\anaconda3\lib\site-packages\arxiv\arxiv.py:681, in Client.__try_parse_feed(self, url, first_page, retries_left, last_err)
#     679 if err is not None:
#     680     if retries_left > 0:
# --> 681         return self.__try_parse_feed(
#     682             url,
#     683             first_page=first_page,
#     684             retries_left=retries_left-1,
#     685             last_err=err,
#     686         )
#     687     # Feed was never returned in self.num_retries tries. Raise the last
#     688     # exception encountered.
#     689     raise err
#
# File ~\anaconda3\lib\site-packages\arxiv\arxiv.py:689, in Client.__try_parse_feed(self, url, first_page, retries_left, last_err)
#     681         return self.__try_parse_feed(
#     682             url,
#     683             first_page=first_page,
#     684             retries_left=retries_left-1,
#     685             last_err=err,
#     686         )
#     687     # Feed was never returned in self.num_retries tries. Raise the last
#     688     # exception encountered.
# --> 689     raise err
#     690 return feed
#
# UnexpectedEmptyPageError: Page of results was unexpectedly empty (http://export.arxiv.org/api/query?search_query=cs.LG&id_list=&sortBy=relevance&sortOrder=descending&start=50000&max_results=2000)

# %%
# Length of paper_results list after executing machine learning code
len(paper_results)
# Out:
# 100000

# %%
# Using of get_results function to append all the papers with 'cs.CC' or Computational Complexity as category.

CC_results = get_results('cs.CC')

for CC_papers in CC_results:
    paper_results.append(CC_papers)

# %%
# Length of paper_results list after executing Computational Complexity code

len(paper_results)
# Out:
# 109451

# %%
# Using of get_results function to append all the papers with 'cs.AR' or Hardware Architecture as category.

AR_results = get_results('cs.AR')

for AR_papers in AR_results:
    paper_results.append(AR_papers)

# %%
# Length of paper_results list after executing Hardware Architecture code

len(paper_results)
# Out:
# 112931

# %% [markdown]
# Once after appending all the papers metadata in to paper_results list. We are now separating and creating list for each of the columns such as titles, corresponding authors, summaries..etc from the paper_results list which contains our metadata. and using pickle package only to view the stored data for the sake of confirmation.

# %%
papers = pickle.dumps(paper_results)

pickle.loads(papers)
# Out:
# [arxiv.Result(entry_id='http://arxiv.org/abs/1511.04326v1', updated=datetime.datetime(2015, 11, 12, 20, 4, 31, tzinfo=datetime.timezone.utc), published=datetime.datetime(2015, 11, 12, 20, 4, 31, tzinfo=datetime.timezone.utc), title='ICON Challenge on Algorithm Selection', authors=[arxiv.Result.Author('Lars Kotthoff')], summary='We present the results of the ICON Challenge on Algorithm Selection.', comment=None, journal_ref=None, doi=None, primary_category='cs.AI', categories=['cs.AI'], links=[arxiv.Result.Link('http://arxiv.org/abs/1511.04326v1', title=None, rel='alternate', content_type=None), arxiv.Result.Link('http://arxiv.org/pdf/1511.04326v1', title='pdf', rel='related', content_type=None)]),
#  arxiv.Result(entry_id='http://arxiv.org/abs/cs/0003012v1', updated=datetime.datetime(2000, 3, 6, 22, 23, tzinfo=datetime.timezone.utc), published=datetime.datetime(2000, 3, 6, 22, 23, tzinfo=datetime.timezone.utc), title='Defeasible Reasoning in OSCAR', authors=[arxiv.Result.Author('John L. Pollock')], summary='This is a system description for the OSCAR defeasible reasoner.', comment='Nonmonotonic Reasoning Workshop, 2000', journal_ref=None, doi=None, primary_category='cs.AI', categories=['cs.AI', 'F.4.1'], links=[arxiv.Result.Link('http://arxiv.org/abs/cs/0003012v1', title=None, rel='alternate', content_type=None), arxiv.Result.Link('http://arxiv.org/pdf/cs/0003012v1', title='pdf', rel='related', content_type=None)]),
#  arxiv.Result(entry_id='http://arxiv.org/abs/cs/0202024v1', updated=datetime.datetime(2002, 2, 18, 15, 23, 6, tzinfo=datetime.timezone.utc), published=datetime.datetime(2002, 2, 18, 15, 23, 6, tzinfo=datetime.timezone.utc), title='A note on Darwiche and Pearl', authors=[arxiv.Result.Author('Daniel Lehmann')], summary="It is shown that Darwiche and Pearl's postulates imply an interesting\nproperty, not noticed by the authors.", comment='A small unpublished remark on a paper by Darwiche and Pearl', journal_ref=None, doi=None, primary_category='cs.AI', categories=['cs.AI', 'I.2.3'], links=[arxiv.Result.Link('http://arxiv.org/abs/cs/0202024v1', title=None, rel='alternate', content_type=None), arxiv.Result.Link('http://arxiv.org/pdf/cs/0202024v1', title='pdf', rel='related', content_type=None)]),
#  arxiv.Result(entry_id='http://arxiv.org/abs/cs/0311004v1', updated=datetime.datetime(2003, 11, 6, 7, 33, 23, tzinfo=datetime.timezone.utc), published=datetime.datetime(2003, 11, 6, 7, 33, 23, tzinfo=datetime.timezone.utc), title='Utility-Probability Duality', authors=[arxiv.Result.Author('Ali Abbas'), arxiv.Result.Author('Jim Matheson')], summary='This paper presents duality between probability distributions and utility\nfunctions.', comment=None, journal_ref=None, doi=None, primary_category='cs.AI', categories=['cs.AI', 'G.3.3'], links=[arxiv.Result.Link('http://arxiv.org/abs/cs/0311004v1', title=None, rel='alternate', content_type=None), arxiv.Result.Link('http://arxiv.org/pdf/cs/0311004v1', title='pdf', rel='related', content_type=None)]),
#  arxiv.Result(entry_id='http://arxiv.org/abs/cs/0508100v1', updated=datetime.datetime(2005, 8, 23, 15, 5, 12, tzinfo=datetime.timezone.utc), published=datetime.datetime(2005, 8, 23, 15, 5, 12, tzinfo=datetime.timezone.utc), title='A primer on Answer Set Programming', authors=[arxiv.Result.Author('Alessandro Provetti')], summary='A introduction to the syntax and Semantics of Answer Set Programming intended\nas an handout to [under]graduate students taking Artificial Intlligence or\nLogic Programming classes.', comment='6 pages', journal_ref=None, doi=None, primary_category='cs.AI', categories=['cs.AI', 'cs.LO', 'D.1.6; I.2.3'], links=[arxiv.Result.Link('http://arxiv.org/abs/cs/0508100v1', title=None, rel='alternate', content_type=None), arxiv.Result.Link('http://arxiv.org/pdf/cs/0508100v1', title='pdf', rel='related', content_type=None)]),
#  arxiv.Result(entry_id='http://arxiv.org/abs/cs/0511015v2', updated=datetime.datetime(2007, 1, 13, 0, 0, 56, tzinfo=datetime.timezone.utc), published=datetime.datetime(2005, 11, 3, 16, 28, 5, tzinfo=datetime.timezone.utc), title='Towards a Hierarchical Model of Consciousness, Intelligence, Mind and Body', authors=[arxiv.Result.Author('Prashant')], summary='This article is taken out.', comment='12 pages, 2 figures', journal_ref=None, doi=None, primary_category='cs.AI', categories=['cs.AI'], links=[arxiv.Result.Link('http://arxiv.org/abs/cs/0511015v2', title=None, rel='alternate', content_type=None), arxiv.Result.Link('http://arxiv.org/pdf/cs/0511015v2', title='pdf', rel='related', content_type=None)]),
#  arxiv.Result(entry_id='http://arxiv.org/abs/cs/0608028v1', updated=datetime.datetime(2006, 8, 4, 20, 26, 25, tzinfo=datetime.timezone.utc), published=datetime.datetime(2006, 8, 4, 20, 26, 25, tzinfo=datetime.timezone.utc), title='Using Sets of Probability Measures to Represent Uncertainty', authors=[arxiv.Result.Author('Joseph Y. Halpern')], summary='I explore the use of sets of probability measures as a representation of\nuncertainty.', comment=None, journal_ref=None, doi=None, primary_category='cs.AI', categories=['cs.AI', 'I.2.4'], links=[arxiv.Result.Link('http://arxiv.org/abs/cs/0608028v1', title=None, rel='alternate', content_type=None), arxiv.Result.Link('http://arxiv.org/pdf/cs/0608028v1', title='pdf', rel='related', content_type=None)]),
#  arxiv.Result(entry_id='http://arxiv.org/abs/0803.1207v3', updated=datetime.datetime(2010, 9, 28, 21, 20, 8, tzinfo=datetime.timezone.utc), published=datetime.datetime(2008, 3, 8, 2, 47, 27, tzinfo=datetime.timezone.utc), title="Serious Flaws in Korf et al.'s Analysis on Time Complexity of A*", authors=[arxiv.Result.Author('Hang Dinh')], summary='This paper has been withdrawn.', comment='This paper has been withdrawn', journal_ref=None, doi=None, primary_category='cs.AI', categories=['cs.AI'], links=[arxiv.Result.Link('http://arxiv.org/abs/0803.1207v3', title=None, rel='alternate', content_type=None), arxiv.Result.Link('http://arxiv.org/pdf/0803.1207v3', title='pdf', rel='related', content_type=None)]),
#  arxiv.Result(entry_id='http://arxiv.org/abs/0809.0458v1', updated=datetime.datetime(2008, 9, 2, 16, 6, 40, tzinfo=datetime.timezone.utc), published=datetime.datetime(2008, 9, 2, 16, 6, 40, tzinfo=datetime.timezone.utc), title='Agent Models of Political Interactions', authors=[arxiv.Result.Author('Eric Engle')], summary='Looks at state interactions from an agent based AI perspective to see state\ninteractions as an example of emergent intelligent behavior. Exposes basic\nprinciples of game theory.', comment='22 pages', journal_ref=None, doi=None, primary_category='cs.AI', categories=['cs.AI', 'cs.GT', 'H.4'], links=[arxiv.Result.Link('http://arxiv.org/abs/0809.0458v1', title=None, rel='alternate', content_type=None), arxiv.Result.Link('http://arxiv.org/pdf/0809.0458v1', title='pdf', rel='related', content_type=None)]),
#  arxiv.Result(entry_id='http://arxiv.org/abs/0905.4570v2', updated=datetime.datetime(2010, 2, 17, 4, 26, 6, tzinfo=datetime.timezone.utc), published=datetime.datetime(2009, 5, 28, 8, 9, 46, tzinfo=datetime.timezone.utc), title='Weak Evolvability Equals Strong Evolvability', authors=[arxiv.Result.Author('Yang Yu'), arxiv.Result.Author('Zhi-Hua Zhou')], summary='An updated version will be uploaded later.', comment='This paper has been withdrawn by the authors', journal_ref=None, doi=None, primary_category='cs.AI', categories=['cs.AI', 'cs.NE'], links=[arxiv.Result.Link('http://arxiv.org/abs/0905.4570v2', title=None, rel='alternate', content_type=None), arxiv.Result.Link('http://arxiv.org/pdf/0905.4570v2', title='pdf', rel='related', content_type=None)]),
#  arxiv.Result(entry_id='http://arxiv.org/abs/0907.4561v1', updated=datetime.datetime(2009, 7, 27, 8, 28, 35, tzinfo=datetime.timezone.utc), published=datetime.datetime(2009, 7, 27, 8, 28, 35, tzinfo=datetime.timezone.utc), title='Fact Sheet on Semantic Web', authors=[arxiv.Result.Author('York Sure')], summary='The report gives an overview about activities on the topic Semantic Web. It\nhas been released as technical report for the project "KTweb -- Connecting\nKnowledge Technologies Communities" in 2003.', comment=None, journal_ref=None, doi=None, primary_category='cs.AI', categories=['cs.AI'], links=[arxiv.Result.Link('http://arxiv.org/abs/0907.4561v1', title=None, rel='alternate', content_type=None), arxiv.Result.Link('http://arxiv.org/pdf/0907.4561v1', title='pdf', rel='related', content_type=None)]),
#  arxiv.Result(entry_id='http://arxiv.org/abs/1008.1710v1', updated=datetime.datetime(2010, 8, 10, 13, 27, 33, tzinfo=datetime.timezone.utc), published=datetime.datetime(2010, 8, 10, 13, 27, 33, tzinfo=datetime.timezone.utc), title='Introduction to the 26th International Conference on Logic Programming Special Issue', authors=[arxiv.Result.Author('Manuel Hermenegildo'), arxiv.Result.Author('Torsten Schaub')], summary='This is the preface to the 26th International Conference on Logic Programming\nSpecial Issue', comment='6 pages', journal_ref=None, doi=None, primary_category='cs.AI', categories=['cs.AI', 'cs.LO'], links=[arxiv.Result.Link('http://arxiv.org/abs/1008.1710v1', title=None, rel='alternate', content_type=None), arxiv.Result.Link('http://arxiv.org/pdf/1008.1710v1', title='pdf', rel='related', content_type=None)]),
#  arxiv.Result(entry_id='http://arxiv.org/abs/1110.3002v1', updated=datetime.datetime(2011, 10, 13, 17, 26, 3, tzinfo=datetime.timezone.utc), published=datetime.datetime(2011, 10, 13, 17, 26, 3, tzinfo=datetime.timezone.utc), title='Are Minds Computable?', authors=[arxiv.Result.Author('Carlos Gershenson')], summary='This essay explores the limits of Turing machines concerning the modeling of\nminds and suggests alternatives to go beyond those limits.', comment='7 pages, comments welcome', journal_ref=None, doi=None, primary_category='cs.AI', categories=['cs.AI', '68T01, 68Q05', 'I.2.0; F.1.1'], links=[arxiv.Result.Link('http://arxiv.org/abs/1110.3002v1', title=None, rel='alternate', content_type=None), arxiv.Result.Link('http://arxiv.org/pdf/1110.3002v1', title='pdf', rel='related', content_type=None)]),
#  arxiv.Result(entry_id='http://arxiv.org/abs/1304.1527v1', updated=datetime.datetime(2013, 3, 27, 19, 40, 21, tzinfo=datetime.timezone.utc), published=datetime.datetime(2013, 3, 27, 19, 40, 21, tzinfo=datetime.timezone.utc), title='Decision under Uncertainty', authors=[arxiv.Result.Author('Philippe Smets')], summary='We derive axiomatically the probability function that should be used to make\ndecisions given any form of underlying uncertainty.', comment='Appears in Proceedings of the Fifth Conference on Uncertainty in\n  Artificial Intelligence (UAI1989)', journal_ref=None, doi=None, primary_category='cs.AI', categories=['cs.AI'], links=[arxiv.Result.Link('http://arxiv.org/abs/1304.1527v1', title=None, rel='alternate', content_type=None), arxiv.Result.Link('http://arxiv.org/pdf/1304.1527v1', title='pdf', rel='related', content_type=None)]),
#  arxiv.Result(entry_id='http://arxiv.org/abs/1304.3846v1', updated=datetime.datetime(2013, 4, 13, 20, 44, 25, tzinfo=datetime.timezone.utc), published=datetime.datetime(2013, 4, 13, 20, 44, 25, tzinfo=datetime.timezone.utc), title='Proceedings of the Thirteenth Conference on Uncertainty in Artificial Intelligence (1997)', authors=[arxiv.Result.Author('Dan Geiger'), arxiv.Result.Author('Prakash Shenoy')], summary='This is the Proceedings of the Thirteenth Conference on Uncertainty in\nArtificial Intelligence, which was held in Providence, RI, August 1-3, 1997', comment=None, journal_ref=None, doi=None, primary_category='cs.AI', categories=['cs.AI'], links=[arxiv.Result.Link('http://arxiv.org/abs/1304.3846v1', title=None, rel='alternate', content_type=None), arxiv.Result.Link('http://arxiv.org/pdf/1304.3846v1', title='pdf', rel='related', content_type=None)]),
#  arxiv.Result(entry_id='http://arxiv.org/abs/1304.3851v1', updated=datetime.datetime(2013, 4, 13, 21, 3, 12, tzinfo=datetime.timezone.utc), published=datetime.datetime(2013, 4, 13, 21, 3, 12, tzinfo=datetime.timezone.utc), title='Proceedings of the Ninth Conference on Uncertainty in Artificial Intelligence (1993)', authors=[arxiv.Result.Author('David Heckerman'), arxiv.Result.Author('E. Mamdani')], summary='This is the Proceedings of the Ninth Conference on Uncertainty in Artificial\nIntelligence, which was held in Washington, DC, July 9-11, 1993', comment=None, journal_ref=None, doi=None, primary_category='cs.AI', categories=['cs.AI'], links=[arxiv.Result.Link('http://arxiv.org/abs/1304.3851v1', title=None, rel='alternate', content_type=None), arxiv.Result.Link('http://arxiv.org/pdf/1304.3851v1', title='pdf', rel='related', content_type=None)]),
#  arxiv.Result(entry_id='http://arxiv.org/abs/1304.3859v1', updated=datetime.datetime(2013, 4, 13, 21, 37, 12, tzinfo=datetime.timezone.utc), published=datetime.datetime(2013, 4, 13, 21, 37, 12, tzinfo=datetime.timezone.utc), title='Proceedings of the Second Conference on Uncertainty in Artificial Intelligence (1986)', authors=[arxiv.Result.Author('Laveen Kanal'), arxiv.Result.Author('John Lemmer')], summary='This is the Proceedings of the Second Conference on Uncertainty in Artificial\nIntelligence, which was held in Philadelphia, PA, August 8-10, 1986', comment=None, journal_ref=None, doi=None, primary_category='cs.AI', categories=['cs.AI'], links=[arxiv.Result.Link('http://arxiv.org/abs/1304.3859v1', title=None, rel='alternate', content_type=None), arxiv.Result.Link('http://arxiv.org/pdf/1304.3859v1', title='pdf', rel='related', content_type=None)]),
#  arxiv.Result(entry_id='http://arxiv.org/abs/1311.0716v1', updated=datetime.datetime(2013, 10, 30, 14, 19, 49, tzinfo=datetime.timezone.utc), published=datetime.datetime(2013, 10, 30, 14, 19, 49, tzinfo=datetime.timezone.utc), title='Artificial Intelligence in Humans', authors=[arxiv.Result.Author('Michael Swan Laufer')], summary='In this paper, I put forward that in many instances, thinking mechanisms are\nequivalent to artificial intelligence modules programmed into the human mind.', comment=None, journal_ref=None, doi=None, primary_category='cs.AI', categories=['cs.AI'], links=[arxiv.Result.Link('http://arxiv.org/abs/1311.0716v1', title=None, rel='alternate', content_type=None), arxiv.Result.Link('http://arxiv.org/pdf/1311.0716v1', title='pdf', rel='related', content_type=None)]),
#  arxiv.Result(entry_id='http://arxiv.org/abs/1311.2912v1', updated=datetime.datetime(2013, 10, 26, 20, 51, 24, tzinfo=datetime.timezone.utc), published=datetime.datetime(2013, 10, 26, 20, 51, 24, tzinfo=datetime.timezone.utc), title='A Misanthropic Reinterpretation of the Chinese Room Problem', authors=[arxiv.Result.Author('Michael S. Laufer')], summary='The chinese room problem asks if computers can think; I ask here if most\nhumans can.', comment=None, journal_ref=None, doi=None, primary_category='cs.AI', categories=['cs.AI'], links=[arxiv.Result.Link('http://arxiv.org/abs/1311.2912v1', title=None, rel='alternate', content_type=None), arxiv.Result.Link('http://arxiv.org/pdf/1311.2912v1', title='pdf', rel='related', content_type=None)]),
#  arxiv.Result(entry_id='http://arxiv.org/abs/1512.09075v2', updated=datetime.datetime(2016, 9, 8, 14, 30, 43, tzinfo=datetime.timezone.utc), published=datetime.datetime(2015, 12, 30, 19, 34, 1, tzinfo=datetime.timezone.utc), title='A Notation for Markov Decision Processes', authors=[arxiv.Result.Author('Philip S. Thomas'), arxiv.Result.Author('Billy Okal')], summary='This paper specifies a notation for Markov decision processes.', comment=None, journal_ref=None, doi=None, primary_category='cs.AI', categories=['cs.AI'], links=[arxiv.Result.Link('http://arxiv.org/abs/1512.09075v2', title=None, rel='alternate', content_type=None), arxiv.Result.Link('http://arxiv.org/pdf/1512.09075v2', title='pdf', rel='related', content_type=None)]),
#  arxiv.Result(entry_id='http://arxiv.org/abs/1601.02865v1', updated=datetime.datetime(2016, 1, 12, 14, 5, 35, tzinfo=datetime.timezone.utc), published=datetime.datetime(2016, 1, 12, 14, 5, 35, tzinfo=datetime.timezone.utc), title="Essence' Description", authors=[arxiv.Result.Author('Peter Nightingale'), arxiv.Result.Author('Andrea Rendl')], summary="A description of the Essence' language as used by the tool Savile Row.", comment=None, journal_ref=None, doi=None, primary_category='cs.AI', categories=['cs.AI'], links=[arxiv.Result.Link('http://arxiv.org/abs/1601.02865v1', title=None, rel='alternate', content_type=None), arxiv.Result.Link('http://arxiv.org/pdf/1601.02865v1', title='pdf', rel='related', content_type=None)]),
#  arxiv.Result(entry_id='http://arxiv.org/abs/1808.08433v1', updated=datetime.datetime(2018, 8, 25, 14, 36, tzinfo=datetime.timezone.utc), published=datetime.datetime(2018, 8, 25, 14, 36, tzinfo=datetime.timezone.utc), title='A Tutorial on Modular Ontology Modeling with Ontology Design Patterns: The Cooking Recipes Ontology', authors=[arxiv.Result.Author('Pascal Hitzler'), arxiv.Result.Author('Adila Krisnadhi')], summary='We provide a detailed example for modular ontology modeling based on ontology\ndesign patterns.', comment=None, journal_ref=None, doi=None, primary_category='cs.AI', categories=['cs.AI'], links=[arxiv.Result.Link('http://arxiv.org/abs/1808.08433v1', title=None, rel='alternate', content_type=None), arxiv.Result.Link('http://arxiv.org/pdf/1808.08433v1', title='pdf', rel='related', content_type=None)]),
#  arxiv.Result(entry_id='http://arxiv.org/abs/0906.2824v1', updated=datetime.datetime(2009, 6, 15, 23, 47, 28, tzinfo=datetime.timezone.utc), published=datetime.datetime(2009, 6, 15, 23, 47, 28, tzinfo=datetime.timezone.utc), title='What Does Artificial Life Tell Us About Death?', authors=[arxiv.Result.Author('Carlos Gershenson')], summary='Short philosophical essay', comment='5 pages', journal_ref='International Journal of Artificial Life Research 2(3):1-5. 2011', doi=None, primary_category='cs.AI', categories=['cs.AI', 'cs.OH'], links=[arxiv.Result.Link('http://arxiv.org/abs/0906.2824v1', title=None, rel='alternate', content_type=None), arxiv.Result.Link('http://arxiv.org/pdf/0906.2824v1', title='pdf', rel='related', content_type=None)]),
#  arxiv.Result(entry_id='http://arxiv.org/abs/1909.13485v1', updated=datetime.datetime(2019, 9, 30, 7, 11, 50, tzinfo=datetime.timezone.utc), published=datetime.datetime(2019, 9, 30, 7, 11, 50, tzinfo=datetime.timezone.utc), title='The Book of Why: Review', authors=[arxiv.Result.Author('Joseph Y. Halpern')], summary='This is a review of "The Book of Why", by Judea Pearl.', comment='To appear in "Artificial Intelligence" journal', journal_ref=None, doi=None, primary_category='cs.AI', categories=['cs.AI'], links=[arxiv.Result.Link('http://arxiv.org/abs/1909.13485v1', title=None, rel='alternate', content_type=None), arxiv.Result.Link('http://arxiv.org/pdf/1909.13485v1', title='pdf', rel='related', content_type=None)]),
#  arxiv.Result(entry_id='http://arxiv.org/abs/1710.03774v2', updated=datetime.datetime(2017, 10, 17, 0, 21, 44, tzinfo=datetime.timezone.utc), published=datetime.datetime(2017, 10, 10, 18, 24, 34, tzinfo=datetime.timezone.utc), title='AI Buzzwords Explained: Multi-Agent Path Finding (MAPF)', authors=[arxiv.Result.Author('Hang Ma'), arxiv.Result.Author('Sven Koenig')], summary='Explanation of the hot topic "multi-agent path finding".', comment=None, journal_ref=None, doi='10.1145/3137574.3137579', primary_category='cs.AI', categories=['cs.AI', 'cs.MA', 'cs.RO'], links=[arxiv.Result.Link('http://dx.doi.org/10.1145/3137574.3137579', title='doi', rel='related', content_type=None), arxiv.Result.Link('http://arxiv.org/abs/1710.03774v2', title=None, rel='alternate', content_type=None), arxiv.Result.Link('http://arxiv.org/pdf/1710.03774v2', title='pdf', rel='related', content_type=None)]),
#  arxiv.Result(entry_id='http://arxiv.org/abs/1810.06018v1', updated=datetime.datetime(2018, 10, 14, 11, 40, 30, tzinfo=datetime.timezone.utc), published=datetime.datetime(2018, 10, 14, 11, 40, 30, tzinfo=datetime.timezone.utc), title='AAAI FSS-18: Artificial Intelligence in Government and Public Sector Proceedings', authors=[arxiv.Result.Author('Frank Stein'), arxiv.Result.Author('Alun Preece'), arxiv.Result.Author('Mihai Boicu')], summary='Proceedings of the AAAI Fall Symposium on Artificial Intelligence in\nGovernment and Public Sector, Arlington, Virginia, USA, October 18-20, 2018', comment=None, journal_ref=None, doi=None, primary_category='cs.AI', categories=['cs.AI'], links=[arxiv.Result.Link('http://arxiv.org/abs/1810.06018v1', title=None, rel='alternate', content_type=None), arxiv.Result.Link('http://arxiv.org/pdf/1810.06018v1', title='pdf', rel='related', content_type=None)]),
#  arxiv.Result(entry_id='http://arxiv.org/abs/1912.01525v1', updated=datetime.datetime(2019, 12, 3, 16, 56, 51, tzinfo=datetime.timezone.utc), published=datetime.datetime(2019, 12, 3, 16, 56, 51, tzinfo=datetime.timezone.utc), title='Self-Learned Formula Synthesis in Set Theory', authors=[arxiv.Result.Author('Chad E. Brown'), arxiv.Result.Author('Thibault Gauthier')], summary='A reinforcement learning algorithm accomplishes the task of synthesizing a\nset-theoretical formula that evaluates to given truth values for given\nassignments.', comment=None, journal_ref=None, doi=None, primary_category='cs.AI', categories=['cs.AI', 'cs.LO'], links=[arxiv.Result.Link('http://arxiv.org/abs/1912.01525v1', title=None, rel='alternate', content_type=None), arxiv.Result.Link('http://arxiv.org/pdf/1912.01525v1', title='pdf', rel='related', content_type=None)]),
#  arxiv.Result(entry_id='http://arxiv.org/abs/2105.03365v1', updated=datetime.datetime(2021, 5, 7, 16, 24, 47, tzinfo=datetime.timezone.utc), published=datetime.datetime(2021, 5, 7, 16, 24, 47, tzinfo=datetime.timezone.utc), title='Accelerating Entrepreneurial Decision-Making Through Hybrid Intelligence', authors=[arxiv.Result.Author('Dominik Dellermann')], summary='Accelerating Entrepreneurial Decision-Making Through Hybrid Intelligence\nDESIGN PARADIGMS AND PRINCIPLES FOR DECISIONAL GUIDANCE IN ENTREPRENEURSHIP', comment=None, journal_ref=None, doi='10.17170/kobra-202004301196', primary_category='cs.AI', categories=['cs.AI', 'cs.HC'], links=[arxiv.Result.Link('http://dx.doi.org/10.17170/kobra-202004301196', title='doi', rel='related', content_type=None), arxiv.Result.Link('http://arxiv.org/abs/2105.03365v1', title=None, rel='alternate', content_type=None), arxiv.Result.Link('http://arxiv.org/pdf/2105.03365v1', title='pdf', rel='related', content_type=None)]),
#  arxiv.Result(entry_id='http://arxiv.org/abs/2107.00749v1', updated=datetime.datetime(2021, 7, 1, 21, 30, 46, tzinfo=datetime.timezone.utc), published=datetime.datetime(2021, 7, 1, 21, 30, 46, tzinfo=datetime.timezone.utc), title='Proof of the impossibility of probabilistic induction', authors=[arxiv.Result.Author('Vaden Masrani')], summary='In this short note I restate and simplify the proof of the impossibility of\nprobabilistic induction from Popper (1992). Other proofs are possible (cf.\nPopper (1985)).', comment=None, journal_ref=None, doi=None, primary_category='cs.AI', categories=['cs.AI'], links=[arxiv.Result.Link('http://arxiv.org/abs/2107.00749v1', title=None, rel='alternate', content_type=None), arxiv.Result.Link('http://arxiv.org/pdf/2107.00749v1', title='pdf', rel='related', content_type=None)]),
#  arxiv.Result(entry_id='http://arxiv.org/abs/2206.02216v1', updated=datetime.datetime(2022, 6, 5, 16, 44, 42, tzinfo=datetime.timezone.utc), published=datetime.datetime(2022, 6, 5, 16, 44, 42, tzinfo=datetime.timezone.utc), title='Sequential Counterfactual Decision-Making Under Confounded Reward', authors=[arxiv.Result.Author('Erik Skalnes')], summary="We investigate the limitations of random trials when the cause of interest is\nconfounded with the effect by formalizing a counterfactual policy-space where\nthe agent's natural predilection is input to a soft-intervention.", comment=None, journal_ref=None, doi=None, primary_category='cs.AI', categories=['cs.AI'], links=[arxiv.Result.Link('http://arxiv.org/abs/2206.02216v1', title=None, rel='alternate', content_type=None), arxiv.Result.Link('http://arxiv.org/pdf/2206.02216v1', title='pdf', rel='related', content_type=None)]),
#  arxiv.Result(entry_id='http://arxiv.org/abs/2208.02495v1', updated=datetime.datetime(2022, 8, 4, 7, 3, 56, tzinfo=datetime.timezone.utc), published=datetime.datetime(2022, 8, 4, 7, 3, 56, tzinfo=datetime.timezone.utc), title='Core Challenge 2022: Solver and Graph Descriptions', authors=[arxiv.Result.Author('Takehide Soh'), arxiv.Result.Author('Yoshio Okamoto'), arxiv.Result.Author('Takehiro Ito')], summary='This paper collects all descriptions of solvers and ISR instances submitted\nto CoRe Challenge 2022.', comment=None, journal_ref=None, doi=None, primary_category='cs.AI', categories=['cs.AI', 'cs.DS'], links=[arxiv.Result.Link('http://arxiv.org/abs/2208.02495v1', title=None, rel='alternate', content_type=None), arxiv.Result.Link('http://arxiv.org/pdf/2208.02495v1', title='pdf', rel='related', content_type=None)]),
#  arxiv.Result(entry_id='http://arxiv.org/abs/2210.01751v1', updated=datetime.datetime(2022, 8, 31, 0, 4, 34, tzinfo=datetime.timezone.utc), published=datetime.datetime(2022, 8, 31, 0, 4, 34, tzinfo=datetime.timezone.utc), title='Proportional algebras, homomorphisms, congruences, and functors', authors=[arxiv.Result.Author('Christian Antić')], summary='This paper introduces proportional algebras as algebras endowed with the\n4-ary analogical proportion relation where the fundamental concepts of\nsubalgebras, homomorphisms, congruences, and functors are constructed.', comment=None, journal_ref=None, doi=None, primary_category='cs.AI', categories=['cs.AI', 'cs.LO'], links=[arxiv.Result.Link('http://arxiv.org/abs/2210.01751v1', title=None, rel='alternate', content_type=None), arxiv.Result.Link('http://arxiv.org/pdf/2210.01751v1', title='pdf', rel='related', content_type=None)]),
#  arxiv.Result(entry_id='http://arxiv.org/abs/2211.02992v1', updated=datetime.datetime(2022, 11, 6, 0, 3, 44, tzinfo=datetime.timezone.utc), published=datetime.datetime(2022, 11, 6, 0, 3, 44, tzinfo=datetime.timezone.utc), title='Foon Creation', authors=[arxiv.Result.Author('Ujwal Saini')], summary='We have designed three search methods for producing the task trees for the\nprovided goal nodes using the Functional Object-Oriented Network. This paper\ndetails the strategy, the procedure, and the outcomes.', comment=None, journal_ref=None, doi=None, primary_category='cs.AI', categories=['cs.AI'], links=[arxiv.Result.Link('http://arxiv.org/abs/2211.02992v1', title=None, rel='alternate', content_type=None), arxiv.Result.Link('http://arxiv.org/pdf/2211.02992v1', title='pdf', rel='related', content_type=None)]),
#  arxiv.Result(entry_id='http://arxiv.org/abs/cs/0201022v2', updated=datetime.datetime(2003, 2, 23, 20, 13, 51, tzinfo=datetime.timezone.utc), published=datetime.datetime(2002, 1, 23, 19, 53, 8, tzinfo=datetime.timezone.utc), title='A theory of experiment', authors=[arxiv.Result.Author('Pierre Albarede')], summary='This article aims at clarifying the language and practice of scientific\nexperiment, mainly by hooking observability on calculability.', comment='19 pages LaTeX article (uses some pstricks) thorough revision 2 see\n  also http://pierre.albarede.free.fr', journal_ref=None, doi=None, primary_category='cs.AI', categories=['cs.AI', 'I.2.4;I.2.6'], links=[arxiv.Result.Link('http://arxiv.org/abs/cs/0201022v2', title=None, rel='alternate', content_type=None), arxiv.Result.Link('http://arxiv.org/pdf/cs/0201022v2', title='pdf', rel='related', content_type=None)]),
#  arxiv.Result(entry_id='http://arxiv.org/abs/cs/0207059v1', updated=datetime.datetime(2002, 7, 15, 11, 30, 16, tzinfo=datetime.timezone.utc), published=datetime.datetime(2002, 7, 15, 11, 30, 16, tzinfo=datetime.timezone.utc), title='Value Based Argumentation Frameworks', authors=[arxiv.Result.Author('T. Bench-Capon')], summary='This paper introduces the notion of value-based argumentation frameworks, an\nextension of the standard argumentation frameworks proposed by Dung, which are\nable toshow how rational decision is possible in cases where arguments derive\ntheir force from the social values their acceptance would promote.', comment=None, journal_ref=None, doi=None, primary_category='cs.AI', categories=['cs.AI', 'I.2.3'], links=[arxiv.Result.Link('http://arxiv.org/abs/cs/0207059v1', title=None, rel='alternate', content_type=None), arxiv.Result.Link('http://arxiv.org/pdf/cs/0207059v1', title='pdf', rel='related', content_type=None)]),
#  arxiv.Result(entry_id='http://arxiv.org/abs/cs/0208019v1', updated=datetime.datetime(2002, 8, 12, 22, 34, 47, tzinfo=datetime.timezone.utc), published=datetime.datetime(2002, 8, 12, 22, 34, 47, tzinfo=datetime.timezone.utc), title='Knowledge Representation', authors=[arxiv.Result.Author('Mikalai Birukou')], summary='This work analyses main features that should be present in knowledge\nrepresentation. It suggests a model for representation and a way to implement\nthis model in software. Representation takes care of both low-level sensor\ninformation and high-level concepts.', comment=None, journal_ref=None, doi=None, primary_category='cs.AI', categories=['cs.AI', 'I.2.0'], links=[arxiv.Result.Link('http://arxiv.org/abs/cs/0208019v1', title=None, rel='alternate', content_type=None), arxiv.Result.Link('http://arxiv.org/pdf/cs/0208019v1', title='pdf', rel='related', content_type=None)]),
#  arxiv.Result(entry_id='http://arxiv.org/abs/cs/0404012v1', updated=datetime.datetime(2004, 4, 5, 17, 23, 7, tzinfo=datetime.timezone.utc), published=datetime.datetime(2004, 4, 5, 17, 23, 7, tzinfo=datetime.timezone.utc), title='Toward the Implementation of Functions in the DLV System (Preliminary Technical Report)', authors=[arxiv.Result.Author('Francesco Calimeri'), arxiv.Result.Author('Nicola Leone')], summary='This document describes the functions as they are treated in the DLV system.\nWe give first the language, then specify the main implementation issues.', comment='7 pages', journal_ref=None, doi=None, primary_category='cs.AI', categories=['cs.AI', 'I.2.4'], links=[arxiv.Result.Link('http://arxiv.org/abs/cs/0404012v1', title=None, rel='alternate', content_type=None), arxiv.Result.Link('http://arxiv.org/pdf/cs/0404012v1', title='pdf', rel='related', content_type=None)]),
#  arxiv.Result(entry_id='http://arxiv.org/abs/cs/0405004v1', updated=datetime.datetime(2004, 5, 3, 20, 25, tzinfo=datetime.timezone.utc), published=datetime.datetime(2004, 5, 3, 20, 25, tzinfo=datetime.timezone.utc), title='Quantum Computers', authors=[arxiv.Result.Author('Archil Avaliani')], summary='This research paper gives an overview of quantum computers - description of\ntheir operation, differences between quantum and silicon computers, major\nconstruction problems of a quantum computer and many other basic aspects. No\nspecial scientific knowledge is necessary for the reader.', comment=None, journal_ref=None, doi=None, primary_category='cs.AI', categories=['cs.AI', 'cs.AR', 'B.0; C.0; K.4.0; I.0'], links=[arxiv.Result.Link('http://arxiv.org/abs/cs/0405004v1', title=None, rel='alternate', content_type=None), arxiv.Result.Link('http://arxiv.org/pdf/cs/0405004v1', title='pdf', rel='related', content_type=None)]),
#  arxiv.Result(entry_id='http://arxiv.org/abs/cs/0501072v1', updated=datetime.datetime(2005, 1, 25, 16, 9, 11, tzinfo=datetime.timezone.utc), published=datetime.datetime(2005, 1, 25, 16, 9, 11, tzinfo=datetime.timezone.utc), title='Inferring knowledge from a large semantic network', authors=[arxiv.Result.Author('Dominique Dutoit'), arxiv.Result.Author('Thierry Poibeau')], summary='In this paper, we present a rich semantic network based on a differential\nanalysis. We then detail implemented measures that take into account common and\ndifferential features between words. In a last section, we describe some\nindustrial applications.', comment=None, journal_ref='Inferring knowledge from a large semantic network (2002) 232-238', doi=None, primary_category='cs.AI', categories=['cs.AI'], links=[arxiv.Result.Link('http://arxiv.org/abs/cs/0501072v1', title=None, rel='alternate', content_type=None), arxiv.Result.Link('http://arxiv.org/pdf/cs/0501072v1', title='pdf', rel='related', content_type=None)]),
#  arxiv.Result(entry_id='http://arxiv.org/abs/cs/0607071v1', updated=datetime.datetime(2006, 7, 14, 12, 44, 24, tzinfo=datetime.timezone.utc), published=datetime.datetime(2006, 7, 14, 12, 44, 24, tzinfo=datetime.timezone.utc), title='Islands for SAT', authors=[arxiv.Result.Author('H. Fang'), arxiv.Result.Author('Y. Kilani'), arxiv.Result.Author('J. H. M. Lee'), arxiv.Result.Author('P. J. Stuckey')], summary='In this note we introduce the notion of islands for restricting local search.\nWe show how we can construct islands for CNF SAT problems, and how much search\nspace can be eliminated by restricting search to the island.', comment='7 pages', journal_ref=None, doi=None, primary_category='cs.AI', categories=['cs.AI'], links=[arxiv.Result.Link('http://arxiv.org/abs/cs/0607071v1', title=None, rel='alternate', content_type=None), arxiv.Result.Link('http://arxiv.org/pdf/cs/0607071v1', title='pdf', rel='related', content_type=None)]),
#  arxiv.Result(entry_id='http://arxiv.org/abs/cs/0610095v1', updated=datetime.datetime(2006, 10, 16, 6, 18, 44, tzinfo=datetime.timezone.utc), published=datetime.datetime(2006, 10, 16, 6, 18, 44, tzinfo=datetime.timezone.utc), title='Solving planning domains with polytree causal graphs is NP-complete', authors=[arxiv.Result.Author('Omer Giménez')], summary='We show that solving planning domains on binary variables with polytree\ncausal graph is \\NP-complete. This is in contrast to a polynomial-time\nalgorithm of Domshlak and Brafman that solves these planning domains for\npolytree causal graphs of bounded indegree.', comment=None, journal_ref=None, doi=None, primary_category='cs.AI', categories=['cs.AI', 'cs.CC', 'I.2.8'], links=[arxiv.Result.Link('http://arxiv.org/abs/cs/0610095v1', title=None, rel='alternate', content_type=None), arxiv.Result.Link('http://arxiv.org/pdf/cs/0610095v1', title='pdf', rel='related', content_type=None)]),
#  arxiv.Result(entry_id='http://arxiv.org/abs/0704.1394v1', updated=datetime.datetime(2007, 4, 11, 10, 59, 56, tzinfo=datetime.timezone.utc), published=datetime.datetime(2007, 4, 11, 10, 59, 56, tzinfo=datetime.timezone.utc), title='Calculating Valid Domains for BDD-Based Interactive Configuration', authors=[arxiv.Result.Author('Tarik Hadzic'), arxiv.Result.Author('Rune Moller Jensen'), arxiv.Result.Author('Henrik Reif Andersen')], summary='In these notes we formally describe the functionality of Calculating Valid\nDomains from the BDD representing the solution space of valid configurations.\nThe formalization is largely based on the CLab configuration framework.', comment=None, journal_ref=None, doi=None, primary_category='cs.AI', categories=['cs.AI'], links=[arxiv.Result.Link('http://arxiv.org/abs/0704.1394v1', title=None, rel='alternate', content_type=None), arxiv.Result.Link('http://arxiv.org/pdf/0704.1394v1', title='pdf', rel='related', content_type=None)]),
#  arxiv.Result(entry_id='http://arxiv.org/abs/0804.1244v1', updated=datetime.datetime(2008, 4, 8, 11, 31, 55, tzinfo=datetime.timezone.utc), published=datetime.datetime(2008, 4, 8, 11, 31, 55, tzinfo=datetime.timezone.utc), title='Geometric Data Analysis, From Correspondence Analysis to Structured Data Analysis (book review)', authors=[arxiv.Result.Author('Fionn Murtagh')], summary='Review of: Brigitte Le Roux and Henry Rouanet, Geometric Data Analysis, From\nCorrespondence Analysis to Structured Data Analysis, Kluwer, Dordrecht, 2004,\nxi+475 pp.', comment='5 pages, 8 citations. Accepted in Journal of Classification', journal_ref='Journal of Classification 25, 137-141, 2008', doi='10.1007/s00357-008-9007-7', primary_category='cs.AI', categories=['cs.AI', 'I.5; G.3; H.3; I.7; J.4'], links=[arxiv.Result.Link('http://dx.doi.org/10.1007/s00357-008-9007-7', title='doi', rel='related', content_type=None), arxiv.Result.Link('http://arxiv.org/abs/0804.1244v1', title=None, rel='alternate', content_type=None), arxiv.Result.Link('http://arxiv.org/pdf/0804.1244v1', title='pdf', rel='related', content_type=None)]),
#  arxiv.Result(entry_id='http://arxiv.org/abs/0806.4511v5', updated=datetime.datetime(2013, 10, 23, 4, 21, 6, tzinfo=datetime.timezone.utc), published=datetime.datetime(2008, 6, 27, 12, 59, 45, tzinfo=datetime.timezone.utc), title='The model of quantum evolution', authors=[arxiv.Result.Author('Konstantin P. Wishnevsky')], summary='This paper has been withdrawn by the author due to extremely unscientific\nerrors.', comment='This paper has been withdrawn', journal_ref=None, doi=None, primary_category='cs.AI', categories=['cs.AI'], links=[arxiv.Result.Link('http://arxiv.org/abs/0806.4511v5', title=None, rel='alternate', content_type=None), arxiv.Result.Link('http://arxiv.org/pdf/0806.4511v5', title='pdf', rel='related', content_type=None)]),
#  arxiv.Result(entry_id='http://arxiv.org/abs/0812.1843v1', updated=datetime.datetime(2008, 12, 10, 19, 2, 31, tzinfo=datetime.timezone.utc), published=datetime.datetime(2008, 12, 10, 19, 2, 31, tzinfo=datetime.timezone.utc), title='Identification of parameters underlying emotions and a classification of emotions', authors=[arxiv.Result.Author('N. Arvind Kumar')], summary='The standard classification of emotions involves categorizing the expression\nof emotions. In this paper, parameters underlying some emotions are identified\nand a new classification based on these parameters is suggested.', comment='6 pages', journal_ref=None, doi=None, primary_category='cs.AI', categories=['cs.AI'], links=[arxiv.Result.Link('http://arxiv.org/abs/0812.1843v1', title=None, rel='alternate', content_type=None), arxiv.Result.Link('http://arxiv.org/pdf/0812.1843v1', title='pdf', rel='related', content_type=None)]),
#  arxiv.Result(entry_id='http://arxiv.org/abs/0901.3608v1', updated=datetime.datetime(2009, 1, 23, 6, 18, 30, tzinfo=datetime.timezone.utc), published=datetime.datetime(2009, 1, 23, 6, 18, 30, tzinfo=datetime.timezone.utc), title='A remark on higher order RUE-resolution with EXTRUE', authors=[arxiv.Result.Author('Christoph Benzmueller')], summary='We show that a prominent counterexample for the completeness of first order\nRUE-resolution does not apply to the higher order RUE-resolution approach\nEXTRUE.', comment='3 pages', journal_ref='SEKI Report (ISSN 1437-4447), Saarland University, 1999', doi=None, primary_category='cs.AI', categories=['cs.AI', 'cs.LO', 'F.4.1; I.2.3'], links=[arxiv.Result.Link('http://arxiv.org/abs/0901.3608v1', title=None, rel='alternate', content_type=None), arxiv.Result.Link('http://arxiv.org/pdf/0901.3608v1', title='pdf', rel='related', content_type=None)]),
#  arxiv.Result(entry_id='http://arxiv.org/abs/0904.0545v2', updated=datetime.datetime(2011, 9, 6, 15, 24, 24, tzinfo=datetime.timezone.utc), published=datetime.datetime(2009, 4, 3, 10, 38, 6, tzinfo=datetime.timezone.utc), title='Time Hopping technique for faster reinforcement learning in simulations', authors=[arxiv.Result.Author('Petar Kormushev'), arxiv.Result.Author('Kohei Nomoto'), arxiv.Result.Author('Fangyan Dong'), arxiv.Result.Author('Kaoru Hirota')], summary='This preprint has been withdrawn by the author for revision', comment='This preprint has been withdrawn by the author for revision', journal_ref=None, doi=None, primary_category='cs.AI', categories=['cs.AI', 'cs.LG', 'cs.RO'], links=[arxiv.Result.Link('http://arxiv.org/abs/0904.0545v2', title=None, rel='alternate', content_type=None), arxiv.Result.Link('http://arxiv.org/pdf/0904.0545v2', title='pdf', rel='related', content_type=None)]),
#  arxiv.Result(entry_id='http://arxiv.org/abs/0905.0192v1', updated=datetime.datetime(2009, 5, 2, 9, 23, 33, tzinfo=datetime.timezone.utc), published=datetime.datetime(2009, 5, 2, 9, 23, 33, tzinfo=datetime.timezone.utc), title='Fuzzy Mnesors', authors=[arxiv.Result.Author('Gilles Champenois')], summary='A fuzzy mnesor space is a semimodule over the positive real numbers. It can\nbe used as theoretical framework for fuzzy sets. Hence we can prove a great\nnumber of properties for fuzzy sets without refering to the membership\nfunctions.', comment=None, journal_ref=None, doi=None, primary_category='cs.AI', categories=['cs.AI'], links=[arxiv.Result.Link('http://arxiv.org/abs/0905.0192v1', title=None, rel='alternate', content_type=None), arxiv.Result.Link('http://arxiv.org/pdf/0905.0192v1', title='pdf', rel='related', content_type=None)]),
#  arxiv.Result(entry_id='http://arxiv.org/abs/0907.0939v2', updated=datetime.datetime(2009, 7, 7, 9, 43, 51, tzinfo=datetime.timezone.utc), published=datetime.datetime(2009, 7, 6, 9, 11, 42, tzinfo=datetime.timezone.utc), title='The Soft Cumulative Constraint', authors=[arxiv.Result.Author('Thierry Petit'), arxiv.Result.Author('Emmanuel Poder')], summary='This research report presents an extension of Cumulative of Choco constraint\nsolver, which is useful to encode over-constrained cumulative problems. This\nnew global constraint uses sweep and task interval violation-based algorithms.', comment=None, journal_ref=None, doi=None, primary_category='cs.AI', categories=['cs.AI'], links=[arxiv.Result.Link('http://arxiv.org/abs/0907.0939v2', title=None, rel='alternate', content_type=None), arxiv.Result.Link('http://arxiv.org/pdf/0907.0939v2', title='pdf', rel='related', content_type=None)]),
#  arxiv.Result(entry_id='http://arxiv.org/abs/0907.2775v1', updated=datetime.datetime(2009, 7, 16, 8, 20, 32, tzinfo=datetime.timezone.utc), published=datetime.datetime(2009, 7, 16, 8, 20, 32, tzinfo=datetime.timezone.utc), title='Modelling Concurrent Behaviors in the Process Specification Language', authors=[arxiv.Result.Author('Dai Tri Man Le')], summary='In this paper, we propose a first-order ontology for generalized stratified\norder structure. We then classify the models of the theory using\nmodel-theoretic techniques. An ontology mapping from this ontology to the core\ntheory of Process Specification Language is also discussed.', comment=None, journal_ref=None, doi=None, primary_category='cs.AI', categories=['cs.AI'], links=[arxiv.Result.Link('http://arxiv.org/abs/0907.2775v1', title=None, rel='alternate', content_type=None), arxiv.Result.Link('http://arxiv.org/pdf/0907.2775v1', title='pdf', rel='related', content_type=None)]),
#  arxiv.Result(entry_id='http://arxiv.org/abs/0907.4100v1', updated=datetime.datetime(2009, 7, 23, 15, 45, 10, tzinfo=datetime.timezone.utc), published=datetime.datetime(2009, 7, 23, 15, 45, 10, tzinfo=datetime.timezone.utc), title='Beyond Turing Machines', authors=[arxiv.Result.Author('Kurt Ammon')], summary='This paper discusses "computational" systems capable of "computing" functions\nnot computable by predefined Turing machines if the systems are not isolated\nfrom their environment. Roughly speaking, these systems can change their finite\ndescriptions by interacting with their environment.', comment=None, journal_ref=None, doi=None, primary_category='cs.AI', categories=['cs.AI'], links=[arxiv.Result.Link('http://arxiv.org/abs/0907.4100v1', title=None, rel='alternate', content_type=None), arxiv.Result.Link('http://arxiv.org/pdf/0907.4100v1', title='pdf', rel='related', content_type=None)]),
#  arxiv.Result(entry_id='http://arxiv.org/abs/1002.0136v1', updated=datetime.datetime(2010, 1, 31, 15, 46, 56, tzinfo=datetime.timezone.utc), published=datetime.datetime(2010, 1, 31, 15, 46, 56, tzinfo=datetime.timezone.utc), title='Dominion -- A constraint solver generator', authors=[arxiv.Result.Author('Lars Kotthoff')], summary='This paper proposes a design for a system to generate constraint solvers that\nare specialised for specific problem models. It describes the design in detail\nand gives preliminary experimental results showing the feasibility and\neffectiveness of the approach.', comment=None, journal_ref=None, doi=None, primary_category='cs.AI', categories=['cs.AI'], links=[arxiv.Result.Link('http://arxiv.org/abs/1002.0136v1', title=None, rel='alternate', content_type=None), arxiv.Result.Link('http://arxiv.org/pdf/1002.0136v1', title='pdf', rel='related', content_type=None)]),
#  arxiv.Result(entry_id='http://arxiv.org/abs/1005.4989v1', updated=datetime.datetime(2010, 5, 27, 5, 59, 56, tzinfo=datetime.timezone.utc), published=datetime.datetime(2010, 5, 27, 5, 59, 56, tzinfo=datetime.timezone.utc), title='A Formalization of the Turing Test', authors=[arxiv.Result.Author('Evgeny Chutchev')], summary='The paper offers a mathematical formalization of the Turing test. This\nformalization makes it possible to establish the conditions under which some\nTuring machine will pass the Turing test and the conditions under which every\nTuring machine (or every Turing machine of the special class) will fail the\nTuring test.', comment='10 pages', journal_ref=None, doi=None, primary_category='cs.AI', categories=['cs.AI'], links=[arxiv.Result.Link('http://arxiv.org/abs/1005.4989v1', title=None, rel='alternate', content_type=None), arxiv.Result.Link('http://arxiv.org/pdf/1005.4989v1', title='pdf', rel='related', content_type=None)]),
#  arxiv.Result(entry_id='http://arxiv.org/abs/1012.1658v1', updated=datetime.datetime(2010, 12, 8, 0, 41, 20, tzinfo=datetime.timezone.utc), published=datetime.datetime(2010, 12, 8, 0, 41, 20, tzinfo=datetime.timezone.utc), title='Creating a new Ontology: a Modular Approach', authors=[arxiv.Result.Author('Julia Dmitrieva'), arxiv.Result.Author('Fons J. Verbeek')], summary='Creating a new Ontology: a Modular Approach', comment='in Adrian Paschke, Albert Burger, Andrea Splendiani, M. Scott\n  Marshall, Paolo Romano: Proceedings of the 3rd International Workshop on\n  Semantic Web Applications and Tools for the Life Sciences, Berlin,Germany,\n  December 8-10, 2010', journal_ref=None, doi=None, primary_category='cs.AI', categories=['cs.AI', 'J.3'], links=[arxiv.Result.Link('http://arxiv.org/abs/1012.1658v1', title=None, rel='alternate', content_type=None), arxiv.Result.Link('http://arxiv.org/pdf/1012.1658v1', title='pdf', rel='related', content_type=None)]),
#  arxiv.Result(entry_id='http://arxiv.org/abs/1103.5708v1', updated=datetime.datetime(2011, 3, 29, 17, 2, 35, tzinfo=datetime.timezone.utc), published=datetime.datetime(2011, 3, 29, 17, 2, 35, tzinfo=datetime.timezone.utc), title='Planning to Be Surprised: Optimal Bayesian Exploration in Dynamic Environments', authors=[arxiv.Result.Author('Yi Sun'), arxiv.Result.Author('Faustino Gomez'), arxiv.Result.Author('Juergen Schmidhuber')], summary='To maximize its success, an AGI typically needs to explore its initially\nunknown world. Is there an optimal way of doing so? Here we derive an\naffirmative answer for a broad class of environments.', comment=None, journal_ref=None, doi=None, primary_category='cs.AI', categories=['cs.AI', 'stat.ML'], links=[arxiv.Result.Link('http://arxiv.org/abs/1103.5708v1', title=None, rel='alternate', content_type=None), arxiv.Result.Link('http://arxiv.org/pdf/1103.5708v1', title='pdf', rel='related', content_type=None)]),
# ...
#  arxiv.Result(entry_id='http://arxiv.org/abs/1009.5290v1', updated=datetime.datetime(2010, 9, 27, 15, 31, 54, tzinfo=datetime.timezone.utc), published=datetime.datetime(2010, 9, 27, 15, 31, 54, tzinfo=datetime.timezone.utc), title='Measuring Similarity of Graphs and their Nodes by Neighbor Matching', authors=[arxiv.Result.Author('Mladen Nikolic')], summary='The problem of measuring similarity of graphs and their nodes is important in\na range of practical problems. There is a number of proposed measures, some of\nthem being based on iterative calculation of similarity between two graphs and\nthe principle that two nodes are as similar as their neighbors are. In our\nwork, we propose one novel method of that sort, with a refined concept of\nsimilarity of two nodes that involves matching of their neighbors. We prove\nconvergence of the proposed method and show that it has some additional\ndesirable properties that, to our knowledge, the existing methods lack. We\nillustrate the method on two specific problems and empirically compare it to\nother methods.', comment=None, journal_ref=None, doi=None, primary_category='cs.AI', categories=['cs.AI', '05C85'], links=[arxiv.Result.Link('http://arxiv.org/abs/1009.5290v1', title=None, rel='alternate', content_type=None), arxiv.Result.Link('http://arxiv.org/pdf/1009.5290v1', title='pdf', rel='related', content_type=None)]),
#  arxiv.Result(entry_id='http://arxiv.org/abs/1010.3177v1', updated=datetime.datetime(2010, 10, 15, 14, 18, 25, tzinfo=datetime.timezone.utc), published=datetime.datetime(2010, 10, 15, 14, 18, 25, tzinfo=datetime.timezone.utc), title='Introduction to the iDian', authors=[arxiv.Result.Author('Xin Rong')], summary='The iDian (previously named as the Operation Agent System) is a framework\ndesigned to enable computer users to operate software in natural language.\nDistinct from current speech-recognition systems, our solution supports\nformat-free combinations of orders, and is open to both developers and\ncustomers. We used a multi-layer structure to build the entire framework,\napproached rule-based natural language processing, and implemented demos\nnarrowing down to Windows, text-editing and a few other applications. This\nessay will firstly give an overview of the entire system, and then scrutinize\nthe functions and structure of the system, and finally discuss the prospective\nde-velopment, esp. on-line interaction functions.', comment='4 pages', journal_ref=None, doi=None, primary_category='cs.AI', categories=['cs.AI'], links=[arxiv.Result.Link('http://arxiv.org/abs/1010.3177v1', title=None, rel='alternate', content_type=None), arxiv.Result.Link('http://arxiv.org/pdf/1010.3177v1', title='pdf', rel='related', content_type=None)]),
#  arxiv.Result(entry_id='http://arxiv.org/abs/1010.4609v1', updated=datetime.datetime(2010, 10, 22, 4, 0, tzinfo=datetime.timezone.utc), published=datetime.datetime(2010, 10, 22, 4, 0, tzinfo=datetime.timezone.utc), title='A Partial Taxonomy of Substitutability and Interchangeability', authors=[arxiv.Result.Author('Shant Karakashian'), arxiv.Result.Author('Robert Woodward'), arxiv.Result.Author('Berthe Y. Choueiry'), arxiv.Result.Author('Steven Prestwhich'), arxiv.Result.Author('Eugene C. Freuder')], summary='Substitutability, interchangeability and related concepts in Constraint\nProgramming were introduced approximately twenty years ago and have given rise\nto considerable subsequent research. We survey this work, classify, and relate\nthe different concepts, and indicate directions for future work, in particular\nwith respect to making connections with research into symmetry breaking. This\npaper is a condensed version of a larger work in progress.', comment="18 pages, The 10th International Workshop on Symmetry in Constraint\n  Satisfaction Problems (SymCon'10)", journal_ref=None, doi=None, primary_category='cs.AI', categories=['cs.AI'], links=[arxiv.Result.Link('http://arxiv.org/abs/1010.4609v1', title=None, rel='alternate', content_type=None), arxiv.Result.Link('http://arxiv.org/pdf/1010.4609v1', title='pdf', rel='related', content_type=None)]),
#  arxiv.Result(entry_id='http://arxiv.org/abs/1011.0098v1', updated=datetime.datetime(2010, 10, 30, 19, 6, 44, tzinfo=datetime.timezone.utc), published=datetime.datetime(2010, 10, 30, 19, 6, 44, tzinfo=datetime.timezone.utc), title='Qualitative Reasoning about Relative Direction on Adjustable Levels of Granularity', authors=[arxiv.Result.Author('Till Mossakowski'), arxiv.Result.Author('Reinhard Moratz')], summary='An important issue in Qualitative Spatial Reasoning is the representation of\nrelative direction. In this paper we present simple geometric rules that enable\nreasoning about relative direction between oriented points. This framework, the\nOriented Point Algebra OPRA_m, has a scalable granularity m. We develop a\nsimple algorithm for computing the OPRA_m composition tables and prove its\ncorrectness. Using a composition table, algebraic closure for a set of OPRA\nstatements is sufficient to solve spatial navigation tasks. And it turns out\nthat scalable granularity is useful in these navigation tasks.', comment=None, journal_ref=None, doi=None, primary_category='cs.AI', categories=['cs.AI'], links=[arxiv.Result.Link('http://arxiv.org/abs/1011.0098v1', title=None, rel='alternate', content_type=None), arxiv.Result.Link('http://arxiv.org/pdf/1011.0098v1', title='pdf', rel='related', content_type=None)]),
#  arxiv.Result(entry_id='http://arxiv.org/abs/1011.0190v1', updated=datetime.datetime(2010, 10, 31, 18, 46, 50, tzinfo=datetime.timezone.utc), published=datetime.datetime(2010, 10, 31, 18, 46, 50, tzinfo=datetime.timezone.utc), title='Prunnig Algorithm of Generation a Minimal Set of Rule Reducts Based on Rough Set Theory', authors=[arxiv.Result.Author('Şahin Emrah Amrahov'), arxiv.Result.Author('Fatih Aybar'), arxiv.Result.Author('Serhat Doğan')], summary='In this paper it is considered rule reduct generation problem, based on Rough\nSet Theory. Rule Reduct Generation (RG) and Modified Rule Generation (MRG)\nalgorithms are well-known. Alternative to these algorithms Pruning Algorithm of\nGeneration A Minimal Set of Rule Reducts, or briefly Pruning Rule Generation\n(PRG) algorithm is developed. PRG algorithm uses tree structured data type. PRG\nalgorithm is compared with RG and MRG algorithms', comment=None, journal_ref=None, doi=None, primary_category='cs.AI', categories=['cs.AI'], links=[arxiv.Result.Link('http://arxiv.org/abs/1011.0190v1', title=None, rel='alternate', content_type=None), arxiv.Result.Link('http://arxiv.org/pdf/1011.0190v1', title='pdf', rel='related', content_type=None)]),
#  arxiv.Result(entry_id='http://arxiv.org/abs/1011.0233v2', updated=datetime.datetime(2010, 11, 4, 1, 26, 45, tzinfo=datetime.timezone.utc), published=datetime.datetime(2010, 11, 1, 1, 2, 39, tzinfo=datetime.timezone.utc), title='Reasoning about Cardinal Directions between Extended Objects: The Hardness Result', authors=[arxiv.Result.Author('Weiming Liu'), arxiv.Result.Author('Sanjiang Li')], summary='The cardinal direction calculus (CDC) proposed by Goyal and Egenhofer is a\nvery expressive qualitative calculus for directional information of extended\nobjects. Early work has shown that consistency checking of complete networks of\nbasic CDC constraints is tractable while reasoning with the CDC in general is\nNP-hard. This paper shows, however, if allowing some constraints unspecified,\nthen consistency checking of possibly incomplete networks of basic CDC\nconstraints is already intractable. This draws a sharp boundary between the\ntractable and intractable subclasses of the CDC. The result is achieved by a\nreduction from the well-known 3-SAT problem.', comment='24 pages, 24 figures', journal_ref=None, doi=None, primary_category='cs.AI', categories=['cs.AI'], links=[arxiv.Result.Link('http://arxiv.org/abs/1011.0233v2', title=None, rel='alternate', content_type=None), arxiv.Result.Link('http://arxiv.org/pdf/1011.0233v2', title='pdf', rel='related', content_type=None)]),
#  arxiv.Result(entry_id='http://arxiv.org/abs/1011.0935v2', updated=datetime.datetime(2010, 11, 5, 14, 14, 33, tzinfo=datetime.timezone.utc), published=datetime.datetime(2010, 11, 3, 16, 50, 22, tzinfo=datetime.timezone.utc), title='Probabilistic Inferences in Bayesian Networks', authors=[arxiv.Result.Author('Jianguo Ding')], summary="Bayesian network is a complete model for the variables and their\nrelationships, it can be used to answer probabilistic queries about them. A\nBayesian network can thus be considered a mechanism for automatically applying\nBayes' theorem to complex problems. In the application of Bayesian networks,\nmost of the work is related to probabilistic inferences. Any variable updating\nin any node of Bayesian networks might result in the evidence propagation\nacross the Bayesian networks. This paper sums up various inference techniques\nin Bayesian networks and provide guidance for the algorithm calculation in\nprobabilistic inference in Bayesian networks.", comment='14 pages, 9 figures, book chapter', journal_ref=None, doi=None, primary_category='cs.AI', categories=['cs.AI', 'cs.NI'], links=[arxiv.Result.Link('http://arxiv.org/abs/1011.0935v2', title=None, rel='alternate', content_type=None), arxiv.Result.Link('http://arxiv.org/pdf/1011.0935v2', title='pdf', rel='related', content_type=None)]),
#  arxiv.Result(entry_id='http://arxiv.org/abs/1011.2304v1', updated=datetime.datetime(2010, 11, 10, 8, 26, 56, tzinfo=datetime.timezone.utc), published=datetime.datetime(2010, 11, 10, 8, 26, 56, tzinfo=datetime.timezone.utc), title='Target tracking in the recommender space: Toward a new recommender system based on Kalman filtering', authors=[arxiv.Result.Author('Samuel Nowakowski'), arxiv.Result.Author('Cédric Bernier'), arxiv.Result.Author('Anne Boyer')], summary='In this paper, we propose a new approach for recommender systems based on\ntarget tracking by Kalman filtering. We assume that users and their seen\nresources are vectors in the multidimensional space of the categories of the\nresources. Knowing this space, we propose an algorithm based on a Kalman filter\nto track users and to predict the best prediction of their future position in\nthe recommendation space.', comment=None, journal_ref=None, doi=None, primary_category='cs.AI', categories=['cs.AI'], links=[arxiv.Result.Link('http://arxiv.org/abs/1011.2304v1', title=None, rel='alternate', content_type=None), arxiv.Result.Link('http://arxiv.org/pdf/1011.2304v1', title='pdf', rel='related', content_type=None)]),
#  arxiv.Result(entry_id='http://arxiv.org/abs/1011.3241v1', updated=datetime.datetime(2010, 11, 14, 17, 57, 40, tzinfo=datetime.timezone.utc), published=datetime.datetime(2010, 11, 14, 17, 57, 40, tzinfo=datetime.timezone.utc), title='New Methods of Analysis of Narrative and Semantics in Support of Interactivity', authors=[arxiv.Result.Author('Fionn Murtagh'), arxiv.Result.Author('Adam Ganz'), arxiv.Result.Author('Joe Reddington')], summary='Our work has focused on support for film or television scriptwriting. Since\nthis involves potentially varied story-lines, we note the implicit or latent\nsupport for interactivity. Furthermore the film, television, games, publishing\nand other sectors are converging, so that cross-over and re-use of one form of\nproduct in another of these sectors is ever more common. Technically our work\nhas been largely based on mathematical algorithms for data clustering and\ndisplay. Operationally, we also discuss how our algorithms can support\ncollective, distributed problem-solving.', comment='17 pages, 6 figures', journal_ref='Entertainment Computing, 2, 115-121, 2011', doi='10.1016/j.entcom.2010.12.008', primary_category='cs.AI', categories=['cs.AI', 'cs.HC', 'stat.AP', 'G.3; I.2.1; H.1.2'], links=[arxiv.Result.Link('http://dx.doi.org/10.1016/j.entcom.2010.12.008', title='doi', rel='related', content_type=None), arxiv.Result.Link('http://arxiv.org/abs/1011.3241v1', title=None, rel='alternate', content_type=None), arxiv.Result.Link('http://arxiv.org/pdf/1011.3241v1', title='pdf', rel='related', content_type=None)]),
#  arxiv.Result(entry_id='http://arxiv.org/abs/1011.3595v1', updated=datetime.datetime(2010, 11, 16, 7, 17, 53, tzinfo=datetime.timezone.utc), published=datetime.datetime(2010, 11, 16, 7, 17, 53, tzinfo=datetime.timezone.utc), title='Optimizing real-time RDF data streams', authors=[arxiv.Result.Author('Joshua Shinavier')], summary='The Resource Description Framework (RDF) provides a common data model for the\nintegration of "real-time" social and sensor data streams with the Web and with\neach other. While there exist numerous protocols and data formats for\nexchanging dynamic RDF data, or RDF updates, these options should be examined\ncarefully in order to enable a Semantic Web equivalent of the high-throughput,\nlow-latency streams of typical Web 2.0, multimedia, and gaming applications.\nThis paper contains a brief survey of RDF update formats and a high-level\ndiscussion of both TCP and UDP-based transport protocols for updates. Its main\ncontribution is the experimental evaluation of a UDP-based architecture which\nserves as a real-world example of a high-performance RDF streaming application\nin an Internet-scale distributed environment.', comment=None, journal_ref=None, doi=None, primary_category='cs.AI', categories=['cs.AI', 'cs.PF'], links=[arxiv.Result.Link('http://arxiv.org/abs/1011.3595v1', title=None, rel='alternate', content_type=None), arxiv.Result.Link('http://arxiv.org/pdf/1011.3595v1', title='pdf', rel='related', content_type=None)]),
#  arxiv.Result(entry_id='http://arxiv.org/abs/1011.5480v1', updated=datetime.datetime(2010, 11, 24, 20, 7, 49, tzinfo=datetime.timezone.utc), published=datetime.datetime(2010, 11, 24, 20, 7, 49, tzinfo=datetime.timezone.utc), title='Bayesian Modeling of a Human MMORPG Player', authors=[arxiv.Result.Author('Gabriel Synnaeve'), arxiv.Result.Author('Pierre Bessiere')], summary='This paper describes an application of Bayesian programming to the control of\nan autonomous avatar in a multiplayer role-playing game (the example is based\non World of Warcraft). We model a particular task, which consists of choosing\nwhat to do and to select which target in a situation where allies and foes are\npresent. We explain the model in Bayesian programming and show how we could\nlearn the conditional probabilities from data gathered during human-played\nsessions.', comment='30th international workshop on Bayesian Inference and Maximum\n  Entropy, Chamonix : France (2010)', journal_ref=None, doi='10.1063/1.3573658', primary_category='cs.AI', categories=['cs.AI'], links=[arxiv.Result.Link('http://dx.doi.org/10.1063/1.3573658', title='doi', rel='related', content_type=None), arxiv.Result.Link('http://arxiv.org/abs/1011.5480v1', title=None, rel='alternate', content_type=None), arxiv.Result.Link('http://arxiv.org/pdf/1011.5480v1', title='pdf', rel='related', content_type=None)]),
#  ...]

# %%
#Extracting all the titles
titles_list = []

for i in paper_results:
    titles_list.append(i.title)

# %%
#Extracting summaries
summary_list = []

for i in paper_results:
    summary_list.append(i.summary)

# %%
#Extracting comments
comments_list = []

for i in paper_results:
    comments_list.append(i.comment)

# %%
#Extracting journal references

journal_ref_list = []

for i in paper_results:
    journal_ref_list.append(i.journal_ref)

# %%
#Extracting DOIs
doi_list = []

for i in paper_results:
    doi_list.append(i.doi)

# %%
#Extracting Entry IDs

entry_ids_list = []

for i in paper_results:
    entry_ids_list.append(i.entry_id)

# %%
#Extracting Authors

authors_list = []

for i in paper_results:
    authors_list.append(str(i.authors))

# %%
#Extracting last updated dates
last_updated_list = []

for i in paper_results:
    last_updated_list.append(str(i.updated))

# %%
#Extracting published dates

published_date_list = []

for i in paper_results:
    published_date_list.append(str(i.published))

# %%
#Extracting the primary category of the papers

primary_category_list = []

for i in paper_results:
    primary_category_list.append(i.primary_category)

# %%
#Extracting all the categories papers could be attributed to

category_list = []

for i in paper_results:
    category_list.append(str(i.categories))

# %%
#Extracting the links which contains both pdf and abs link

links_list = []

for i in paper_results:
        links_list.append(str(i.links))

# %%
# Extracting the pdf link of papers

pdf_url_list = []

for i in paper_results:
        pdf_url_list.append(i.pdf_url)

# %% [markdown]
# After creating lists for each of the attributes. We are now going to stack them as columns for a dataframe that hosts all this data called papers_df

# %%
#I am using the np.column_stack to stack these lists as columns in to single dataframe.

papers_df = pd.DataFrame(np.column_stack([titles_list,
                                          authors_list,
                                          summary_list,
                                          comments_list,
                                          journal_ref_list,
                                          doi_list,
                                          entry_ids_list,
                                          last_updated_list,
                                          published_date_list,
                                          primary_category_list,
                                          category_list,
                                          links_list,
                                          pdf_url_list]),
                         columns=['Title',
                                  'Author',
                                  'Summary',
                                  'Comment',
                                  'Journal_ref',
                                  'DOI',
                                  'Entry_ID',
                                  'Last_updated',
                                  'Published_date',
                                  'Primary_category',
                                  'Category',
                                  'Links',
                                  'PDF_URL'])

# %%
papers_df
# Out:
#                                                     Title  \
# 0                   ICON Challenge on Algorithm Selection
# 1                           Defeasible Reasoning in OSCAR
# 2                            A note on Darwiche and Pearl
# 3                             Utility-Probability Duality
# 4                      A primer on Answer Set Programming
# ...                                                   ...
# 112926  Benchmarking Edge Computing Devices for Grape ...
# 112927  Profile-Guided Parallel Task Extraction and Ex...
# 112928  Implementing Neural Network-Based Equalizers i...
# 112929  First-Generation Inference Accelerator Deploym...
# 112930  Applications and Techniques for Fast Machine L...
#
#                                                    Author  \
# 0                  [arxiv.Result.Author('Lars Kotthoff')]
# 1                [arxiv.Result.Author('John L. Pollock')]
# 2                 [arxiv.Result.Author('Daniel Lehmann')]
# 3       [arxiv.Result.Author('Ali Abbas'), arxiv.Resul...
# 4            [arxiv.Result.Author('Alessandro Provetti')]
# ...                                                   ...
# 112926  [arxiv.Result.Author('Sandro Costa Magalhães')...
# 112927  [arxiv.Result.Author('Liangliang Chang'), arxi...
# 112928  [arxiv.Result.Author('Pedro J. Freire'), arxiv...
# 112929  [arxiv.Result.Author('Michael Anderson'), arxi...
# 112930  [arxiv.Result.Author('Allison McCarn Deiana'),...
#
#                                                   Summary  \
# 0       We present the results of the ICON Challenge o...
# 1       This is a system description for the OSCAR def...
# 2       It is shown that Darwiche and Pearl's postulat...
# 3       This paper presents duality between probabilit...
# 4       A introduction to the syntax and Semantics of ...
# ...                                                   ...
# 112926  Purpose: Visual perception enables robots to p...
# 112927  In this study, we introduce a methodology for ...
# 112928  In this work, we demonstrate the offline FPGA ...
# 112929  In this paper, we provide a deep dive into the...
# 112930  In this community review report, we discuss ap...
#
#                                                   Comment  \
# 0                                                    None
# 1                   Nonmonotonic Reasoning Workshop, 2000
# 2       A small unpublished remark on a paper by Darwi...
# 3                                                    None
# 4                                                 6 pages
# ...                                                   ...
# 112926                                               None
# 112927                     8 pages, accepted by ISPA 2022
# 112928  Invited paper at Journal of Lightwave Technolo...
# 112929                                               None
# 112930                     66 pages, 13 figures, 5 tables
#
#                      Journal_ref                             DOI  \
# 0                           None                            None
# 1                           None                            None
# 2                           None                            None
# 3                           None                            None
# 4                           None                            None
# ...                          ...                             ...
# 112926  EAAI, 117, 105604 (2022)  10.1016/j.engappai.2022.105604
# 112927                      None                            None
# 112928                      None                            None
# 112929                      None                            None
# 112930                      None                            None
#
#                                  Entry_ID               Last_updated  \
# 0       http://arxiv.org/abs/1511.04326v1  2015-11-12 20:04:31+00:00
# 1       http://arxiv.org/abs/cs/0003012v1  2000-03-06 22:23:00+00:00
# 2       http://arxiv.org/abs/cs/0202024v1  2002-02-18 15:23:06+00:00
# 3       http://arxiv.org/abs/cs/0311004v1  2003-11-06 07:33:23+00:00
# 4       http://arxiv.org/abs/cs/0508100v1  2005-08-23 15:05:12+00:00
# ...                                   ...                        ...
# 112926  http://arxiv.org/abs/2211.11647v1  2022-11-21 17:02:33+00:00
# 112927  http://arxiv.org/abs/2211.14547v1  2022-11-26 12:01:40+00:00
# 112928  http://arxiv.org/abs/2212.04703v1  2022-12-09 07:28:45+00:00
# 112929  http://arxiv.org/abs/2107.04140v3  2021-08-04 21:51:51+00:00
# 112930  http://arxiv.org/abs/2110.13041v1  2021-10-25 15:25:25+00:00
#
#                    Published_date Primary_category  \
# 0       2015-11-12 20:04:31+00:00            cs.AI
# 1       2000-03-06 22:23:00+00:00            cs.AI
# 2       2002-02-18 15:23:06+00:00            cs.AI
# 3       2003-11-06 07:33:23+00:00            cs.AI
# 4       2005-08-23 15:05:12+00:00            cs.AI
# ...                           ...              ...
# 112926  2022-11-21 17:02:33+00:00            cs.CV
# 112927  2022-11-26 12:01:40+00:00            cs.DC
# 112928  2022-12-09 07:28:45+00:00          eess.SP
# 112929  2021-07-08 22:52:42+00:00            cs.AR
# 112930  2021-10-25 15:25:25+00:00            cs.LG
#
#                                                  Category  \
# 0                                               ['cs.AI']
# 1                                      ['cs.AI', 'F.4.1']
# 2                                      ['cs.AI', 'I.2.3']
# 3                                      ['cs.AI', 'G.3.3']
# 4                      ['cs.AI', 'cs.LO', 'D.1.6; I.2.3']
# ...                                                   ...
# 112926  ['cs.CV', 'cs.AR', 'cs.DC', '62M45, 62P30, 68Q...
# 112927                                 ['cs.DC', 'cs.AR']
# 112928             ['eess.SP', 'cs.AR', 'cs.CC', 'cs.LG']
# 112929                                          ['cs.AR']
# 112930  ['cs.LG', 'cs.AR', 'physics.data-an', 'physics...
#
#                                                     Links  \
# 0       [arxiv.Result.Link('http://arxiv.org/abs/1511....
# 1       [arxiv.Result.Link('http://arxiv.org/abs/cs/00...
# 2       [arxiv.Result.Link('http://arxiv.org/abs/cs/02...
# 3       [arxiv.Result.Link('http://arxiv.org/abs/cs/03...
# 4       [arxiv.Result.Link('http://arxiv.org/abs/cs/05...
# ...                                                   ...
# 112926  [arxiv.Result.Link('http://dx.doi.org/10.1016/...
# 112927  [arxiv.Result.Link('http://arxiv.org/abs/2211....
# 112928  [arxiv.Result.Link('http://arxiv.org/abs/2212....
# 112929  [arxiv.Result.Link('http://arxiv.org/abs/2107....
# 112930  [arxiv.Result.Link('http://arxiv.org/abs/2110....
#
#                                   PDF_URL
# 0       http://arxiv.org/pdf/1511.04326v1
# 1       http://arxiv.org/pdf/cs/0003012v1
# 2       http://arxiv.org/pdf/cs/0202024v1
# 3       http://arxiv.org/pdf/cs/0311004v1
# 4       http://arxiv.org/pdf/cs/0508100v1
# ...                                   ...
# 112926  http://arxiv.org/pdf/2211.11647v1
# 112927  http://arxiv.org/pdf/2211.14547v1
# 112928  http://arxiv.org/pdf/2212.04703v1
# 112929  http://arxiv.org/pdf/2107.04140v3
# 112930  http://arxiv.org/pdf/2110.13041v1
#
# [112931 rows x 13 columns]

# %% [markdown]
# Filtering the data according to our needs. i.e Published date years (2017 - 2021) & primary category of ('cs.AI','cs.LG','cs.CC','cs.AR')

# %%
# First filteration of published dates from 2017 to 2021.

papers_df = papers_df[(papers_df['Published_date'] > '2017-01-01') & (papers_df['Published_date'] < '2021-12-31')]

# %%
#2nd filteration step. primary category should only be cs.AI|cs.CC|cs.LG|cs.AR

papers_df = papers_df[papers_df['Primary_category'].str.contains('cs.AI|cs.CC|cs.LG|cs.AR')]

# %%
papers_df
# Out:
#                                                     Title  \
# 21      A Tutorial on Modular Ontology Modeling with O...
# 23                                The Book of Why: Review
# 24      AI Buzzwords Explained: Multi-Agent Path Findi...
# 25      AAAI FSS-18: Artificial Intelligence in Govern...
# 26           Self-Learned Formula Synthesis in Set Theory
# ...                                                   ...
# 112872  Brain-inspired Cognition in Next Generation Ra...
# 112873  MC-CIM: Compute-in-Memory with Monte-Carlo Dro...
# 112878  Logic Shrinkage: Learned FPGA Netlist Sparsity...
# 112929  First-Generation Inference Accelerator Deploym...
# 112930  Applications and Techniques for Fast Machine L...
#
#                                                    Author  \
# 21      [arxiv.Result.Author('Pascal Hitzler'), arxiv....
# 23             [arxiv.Result.Author('Joseph Y. Halpern')]
# 24      [arxiv.Result.Author('Hang Ma'), arxiv.Result....
# 25      [arxiv.Result.Author('Frank Stein'), arxiv.Res...
# 26      [arxiv.Result.Author('Chad E. Brown'), arxiv.R...
# ...                                                   ...
# 112872  [arxiv.Result.Author('Asif Ali Khan'), arxiv.R...
# 112873  [arxiv.Result.Author('Priyesh Shukla'), arxiv....
# 112878  [arxiv.Result.Author('Erwei Wang'), arxiv.Resu...
# 112929  [arxiv.Result.Author('Michael Anderson'), arxi...
# 112930  [arxiv.Result.Author('Allison McCarn Deiana'),...
#
#                                                   Summary  \
# 21      We provide a detailed example for modular onto...
# 23      This is a review of "The Book of Why", by Jude...
# 24      Explanation of the hot topic "multi-agent path...
# 25      Proceedings of the AAAI Fall Symposium on Arti...
# 26      A reinforcement learning algorithm accomplishe...
# ...                                                   ...
# 112872  Hyperdimensional computing (HDC) is an emergin...
# 112873  We propose MC-CIM, a compute-in-memory (CIM) f...
# 112878  FPGA-specific DNN architectures using the nati...
# 112929  In this paper, we provide a deep dive into the...
# 112930  In this community review report, we discuss ap...
#
#                                                   Comment Journal_ref  \
# 21                                                   None        None
# 23         To appear in "Artificial Intelligence" journal        None
# 24                                                   None        None
# 25                                                   None        None
# 26                                                   None        None
# ...                                                   ...         ...
# 112872  Preprint, accepted for publication, ACM Transa...        None
# 112873                                               None        None
# 112878  Accepted manuscript uploaded 04/12/21. DOA 22/...        None
# 112929                                               None        None
# 112930                     66 pages, 13 figures, 5 tables        None
#
#                             DOI                           Entry_ID  \
# 21                         None  http://arxiv.org/abs/1808.08433v1
# 23                         None  http://arxiv.org/abs/1909.13485v1
# 24      10.1145/3137574.3137579  http://arxiv.org/abs/1710.03774v2
# 25                         None  http://arxiv.org/abs/1810.06018v1
# 26                         None  http://arxiv.org/abs/1912.01525v1
# ...                         ...                                ...
# 112872          10.1145/3524071  http://arxiv.org/abs/2111.02246v2
# 112873                     None  http://arxiv.org/abs/2111.07125v1
# 112878  10.1145/3490422.3502360  http://arxiv.org/abs/2112.02346v2
# 112929                     None  http://arxiv.org/abs/2107.04140v3
# 112930                     None  http://arxiv.org/abs/2110.13041v1
#
#                      Last_updated             Published_date Primary_category  \
# 21      2018-08-25 14:36:00+00:00  2018-08-25 14:36:00+00:00            cs.AI
# 23      2019-09-30 07:11:50+00:00  2019-09-30 07:11:50+00:00            cs.AI
# 24      2017-10-17 00:21:44+00:00  2017-10-10 18:24:34+00:00            cs.AI
# 25      2018-10-14 11:40:30+00:00  2018-10-14 11:40:30+00:00            cs.AI
# 26      2019-12-03 16:56:51+00:00  2019-12-03 16:56:51+00:00            cs.AI
# ...                           ...                        ...              ...
# 112872  2022-03-15 22:34:53+00:00  2021-11-03 14:21:39+00:00            cs.LG
# 112873  2021-11-13 14:50:48+00:00  2021-11-13 14:50:48+00:00            cs.LG
# 112878  2022-01-02 12:19:38+00:00  2021-12-04 14:23:24+00:00            cs.LG
# 112929  2021-08-04 21:51:51+00:00  2021-07-08 22:52:42+00:00            cs.AR
# 112930  2021-10-25 15:25:25+00:00  2021-10-25 15:25:25+00:00            cs.LG
#
#                                                  Category  \
# 21                                              ['cs.AI']
# 23                                              ['cs.AI']
# 24                            ['cs.AI', 'cs.MA', 'cs.RO']
# 25                                              ['cs.AI']
# 26                                     ['cs.AI', 'cs.LO']
# ...                                                   ...
# 112872                        ['cs.LG', 'cs.AR', 'cs.ET']
# 112873             ['cs.LG', 'cs.AR', 'cs.RO', 'eess.IV']
# 112878                                 ['cs.LG', 'cs.AR']
# 112929                                          ['cs.AR']
# 112930  ['cs.LG', 'cs.AR', 'physics.data-an', 'physics...
#
#                                                     Links  \
# 21      [arxiv.Result.Link('http://arxiv.org/abs/1808....
# 23      [arxiv.Result.Link('http://arxiv.org/abs/1909....
# 24      [arxiv.Result.Link('http://dx.doi.org/10.1145/...
# 25      [arxiv.Result.Link('http://arxiv.org/abs/1810....
# 26      [arxiv.Result.Link('http://arxiv.org/abs/1912....
# ...                                                   ...
# 112872  [arxiv.Result.Link('http://dx.doi.org/10.1145/...
# 112873  [arxiv.Result.Link('http://arxiv.org/abs/2111....
# 112878  [arxiv.Result.Link('http://dx.doi.org/10.1145/...
# 112929  [arxiv.Result.Link('http://arxiv.org/abs/2107....
# 112930  [arxiv.Result.Link('http://arxiv.org/abs/2110....
#
#                                   PDF_URL
# 21      http://arxiv.org/pdf/1808.08433v1
# 23      http://arxiv.org/pdf/1909.13485v1
# 24      http://arxiv.org/pdf/1710.03774v2
# 25      http://arxiv.org/pdf/1810.06018v1
# 26      http://arxiv.org/pdf/1912.01525v1
# ...                                   ...
# 112872  http://arxiv.org/pdf/2111.02246v2
# 112873  http://arxiv.org/pdf/2111.07125v1
# 112878  http://arxiv.org/pdf/2112.02346v2
# 112929  http://arxiv.org/pdf/2107.04140v3
# 112930  http://arxiv.org/pdf/2110.13041v1
#
# [49668 rows x 13 columns]

# %% [markdown]
# Cleaning : Our dataframe is shaping up. But results had 'arxiv.result.Author' in side the cells. We are now cleaning the data to see authors names as is, in the next step.

# %%
papers_df['Author'] = papers_df['Author'].str.replace('arxiv.Result.Author', '')

papers_df['Author'] = papers_df['Author'].str.replace('[', '')

papers_df['Author'] = papers_df['Author'].str.replace(']', '')

papers_df['Author'] = papers_df['Author'].str.replace('(', '')

papers_df['Author'] = papers_df['Author'].str.replace(')', '')

papers_df['Links'] = papers_df['Links'].str.replace('arxiv.Result.Link', '')

papers_df['Links'] = papers_df['Links'].str.replace('[', '')

papers_df['Links'] = papers_df['Links'].str.replace(']', '')

papers_df['Links'] = papers_df['Links'].str.replace('(', '')

papers_df['Links'] = papers_df['Links'].str.replace(')', '')

papers_df['Category'] = papers_df['Category'].str.replace('[', '')

papers_df['Category'] = papers_df['Category'].str.replace(']', '')
# Out:
# C:\Users\nagas\AppData\Local\Temp\ipykernel_12548\533585869.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   papers_df['Author'] = papers_df['Author'].str.replace('arxiv.Result.Author', '')
# C:\Users\nagas\AppData\Local\Temp\ipykernel_12548\533585869.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   papers_df['Author'] = papers_df['Author'].str.replace('[', '')
# C:\Users\nagas\AppData\Local\Temp\ipykernel_12548\533585869.py:5: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   papers_df['Author'] = papers_df['Author'].str.replace(']', '')
# C:\Users\nagas\AppData\Local\Temp\ipykernel_12548\533585869.py:7: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   papers_df['Author'] = papers_df['Author'].str.replace('(', '')
# C:\Users\nagas\AppData\Local\Temp\ipykernel_12548\533585869.py:9: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   papers_df['Author'] = papers_df['Author'].str.replace(')', '')
# C:\Users\nagas\AppData\Local\Temp\ipykernel_12548\533585869.py:11: FutureWarning: The default value of regex will change from True to False in a future version.
#   papers_df['Links'] = papers_df['Links'].str.replace('arxiv.Result.Link', '')
# C:\Users\nagas\AppData\Local\Temp\ipykernel_12548\533585869.py:13: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   papers_df['Links'] = papers_df['Links'].str.replace('[', '')
# C:\Users\nagas\AppData\Local\Temp\ipykernel_12548\533585869.py:15: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   papers_df['Links'] = papers_df['Links'].str.replace(']', '')
# C:\Users\nagas\AppData\Local\Temp\ipykernel_12548\533585869.py:17: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   papers_df['Links'] = papers_df['Links'].str.replace('(', '')
# C:\Users\nagas\AppData\Local\Temp\ipykernel_12548\533585869.py:19: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   papers_df['Links'] = papers_df['Links'].str.replace(')', '')
# C:\Users\nagas\AppData\Local\Temp\ipykernel_12548\533585869.py:21: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   papers_df['Category'] = papers_df['Category'].str.replace('[', '')
# C:\Users\nagas\AppData\Local\Temp\ipykernel_12548\533585869.py:23: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   papers_df['Category'] = papers_df['Category'].str.replace(']', '')

# %%
papers_df
# Out:
#                                                     Title  \
# 21      A Tutorial on Modular Ontology Modeling with O...
# 23                                The Book of Why: Review
# 24      AI Buzzwords Explained: Multi-Agent Path Findi...
# 25      AAAI FSS-18: Artificial Intelligence in Govern...
# 26           Self-Learned Formula Synthesis in Set Theory
# ...                                                   ...
# 112872  Brain-inspired Cognition in Next Generation Ra...
# 112873  MC-CIM: Compute-in-Memory with Monte-Carlo Dro...
# 112878  Logic Shrinkage: Learned FPGA Netlist Sparsity...
# 112929  First-Generation Inference Accelerator Deploym...
# 112930  Applications and Techniques for Fast Machine L...
#
#                                                    Author  \
# 21                    'Pascal Hitzler', 'Adila Krisnadhi'
# 23                                    'Joseph Y. Halpern'
# 24                               'Hang Ma', 'Sven Koenig'
# 25            'Frank Stein', 'Alun Preece', 'Mihai Boicu'
# 26                   'Chad E. Brown', 'Thibault Gauthier'
# ...                                                   ...
# 112872  'Asif Ali Khan', 'Sebastien Ollivier', 'Stephe...
# 112873  'Priyesh Shukla', 'Shamma Nasrin', 'Nastaran D...
# 112878  'Erwei Wang', 'James J. Davis', 'Georgios-Ilia...
# 112929  'Michael Anderson', 'Benny Chen', 'Stephen Che...
# 112930  'Allison McCarn Deiana', 'Nhan Tran', 'Joshua ...
#
#                                                   Summary  \
# 21      We provide a detailed example for modular onto...
# 23      This is a review of "The Book of Why", by Jude...
# 24      Explanation of the hot topic "multi-agent path...
# 25      Proceedings of the AAAI Fall Symposium on Arti...
# 26      A reinforcement learning algorithm accomplishe...
# ...                                                   ...
# 112872  Hyperdimensional computing (HDC) is an emergin...
# 112873  We propose MC-CIM, a compute-in-memory (CIM) f...
# 112878  FPGA-specific DNN architectures using the nati...
# 112929  In this paper, we provide a deep dive into the...
# 112930  In this community review report, we discuss ap...
#
#                                                   Comment Journal_ref  \
# 21                                                   None        None
# 23         To appear in "Artificial Intelligence" journal        None
# 24                                                   None        None
# 25                                                   None        None
# 26                                                   None        None
# ...                                                   ...         ...
# 112872  Preprint, accepted for publication, ACM Transa...        None
# 112873                                               None        None
# 112878  Accepted manuscript uploaded 04/12/21. DOA 22/...        None
# 112929                                               None        None
# 112930                     66 pages, 13 figures, 5 tables        None
#
#                             DOI                           Entry_ID  \
# 21                         None  http://arxiv.org/abs/1808.08433v1
# 23                         None  http://arxiv.org/abs/1909.13485v1
# 24      10.1145/3137574.3137579  http://arxiv.org/abs/1710.03774v2
# 25                         None  http://arxiv.org/abs/1810.06018v1
# 26                         None  http://arxiv.org/abs/1912.01525v1
# ...                         ...                                ...
# 112872          10.1145/3524071  http://arxiv.org/abs/2111.02246v2
# 112873                     None  http://arxiv.org/abs/2111.07125v1
# 112878  10.1145/3490422.3502360  http://arxiv.org/abs/2112.02346v2
# 112929                     None  http://arxiv.org/abs/2107.04140v3
# 112930                     None  http://arxiv.org/abs/2110.13041v1
#
#                      Last_updated             Published_date Primary_category  \
# 21      2018-08-25 14:36:00+00:00  2018-08-25 14:36:00+00:00            cs.AI
# 23      2019-09-30 07:11:50+00:00  2019-09-30 07:11:50+00:00            cs.AI
# 24      2017-10-17 00:21:44+00:00  2017-10-10 18:24:34+00:00            cs.AI
# 25      2018-10-14 11:40:30+00:00  2018-10-14 11:40:30+00:00            cs.AI
# 26      2019-12-03 16:56:51+00:00  2019-12-03 16:56:51+00:00            cs.AI
# ...                           ...                        ...              ...
# 112872  2022-03-15 22:34:53+00:00  2021-11-03 14:21:39+00:00            cs.LG
# 112873  2021-11-13 14:50:48+00:00  2021-11-13 14:50:48+00:00            cs.LG
# 112878  2022-01-02 12:19:38+00:00  2021-12-04 14:23:24+00:00            cs.LG
# 112929  2021-08-04 21:51:51+00:00  2021-07-08 22:52:42+00:00            cs.AR
# 112930  2021-10-25 15:25:25+00:00  2021-10-25 15:25:25+00:00            cs.LG
#
#                                                  Category  \
# 21                                                'cs.AI'
# 23                                                'cs.AI'
# 24                              'cs.AI', 'cs.MA', 'cs.RO'
# 25                                                'cs.AI'
# 26                                       'cs.AI', 'cs.LO'
# ...                                                   ...
# 112872                          'cs.LG', 'cs.AR', 'cs.ET'
# 112873               'cs.LG', 'cs.AR', 'cs.RO', 'eess.IV'
# 112878                                   'cs.LG', 'cs.AR'
# 112929                                            'cs.AR'
# 112930  'cs.LG', 'cs.AR', 'physics.data-an', 'physics....
#
#                                                     Links  \
# 21      'http://arxiv.org/abs/1808.08433v1', title=Non...
# 23      'http://arxiv.org/abs/1909.13485v1', title=Non...
# 24      'http://dx.doi.org/10.1145/3137574.3137579', t...
# 25      'http://arxiv.org/abs/1810.06018v1', title=Non...
# 26      'http://arxiv.org/abs/1912.01525v1', title=Non...
# ...                                                   ...
# 112872  'http://dx.doi.org/10.1145/3524071', title='do...
# 112873  'http://arxiv.org/abs/2111.07125v1', title=Non...
# 112878  'http://dx.doi.org/10.1145/3490422.3502360', t...
# 112929  'http://arxiv.org/abs/2107.04140v3', title=Non...
# 112930  'http://arxiv.org/abs/2110.13041v1', title=Non...
#
#                                   PDF_URL
# 21      http://arxiv.org/pdf/1808.08433v1
# 23      http://arxiv.org/pdf/1909.13485v1
# 24      http://arxiv.org/pdf/1710.03774v2
# 25      http://arxiv.org/pdf/1810.06018v1
# 26      http://arxiv.org/pdf/1912.01525v1
# ...                                   ...
# 112872  http://arxiv.org/pdf/2111.02246v2
# 112873  http://arxiv.org/pdf/2111.07125v1
# 112878  http://arxiv.org/pdf/2112.02346v2
# 112929  http://arxiv.org/pdf/2107.04140v3
# 112930  http://arxiv.org/pdf/2110.13041v1
#
# [49668 rows x 13 columns]

# %% [markdown]
# Finally saving the output to a csv file. This csv file is used in task 2

# %%
#finally saving the output to a csv file.

papers_df.to_csv('Arxiv_Papers_Results.csv',index = False)
